# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# EDA : BUSINEES

# %% [markdown]
# Las colunnas son business_id, name, address, city, state, postal_code, latitude, longitude, stars,review_count,is_open, attributes, categories, hours.

# %%
df_businees= pd.read_pickle(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\business.pkl")
df_businees.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
# 3  39.955505  -75.155564   4.0           80  ...   NaN         NaN      NaN
# 4  40.338183  -75.471659   4.5           13  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 2       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 3       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 4       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [5 rows x 28 columns]

# %%
# Cantidad de filas y columnas
df_businees.shape
# Out:
# (150346, 28)

# %%
# Ver los tipos de datos de cada columna
print(df_businees.dtypes)
# Out:
# business_id     object
# name            object
# address         object
# city            object
# state           object
# postal_code     object
# latitude        object
# longitude       object
# stars           object
# review_count    object
# is_open         object
# attributes      object
# categories      object
# hours           object
# business_id     object
# name            object
# address         object
# city            object
# state           object
# postal_code     object
# latitude        object
# longitude       object
# stars           object
# review_count    object
# is_open         object
# attributes      object
# categories      object
# hours           object
# dtype: object

# %%
# Mostrar información del DataFrame
print("\nInformación del DataFrame:")
df_businees.info()
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
#  17  city          5 non-null       object
#  18  state         5 non-null       object
#  19  postal_code   5 non-null       object
#  20  latitude      5 non-null       object
#  21  longitude     5 non-null       object
#  22  stars         5 non-null       object
#  23  review_count  5 non-null       object
#  24  is_open       5 non-null       object
#  25  attributes    5 non-null       object
#  26  categories    5 non-null       object
#  27  hours         5 non-null       object
# dtypes: object(28)
# memory usage: 33.3+ MB

# %%
# Mostrar las últimas filas del DataFrame
print("\nÚltimas filas del DataFrame:")
print(df_businees.tail())
# Out:
# Últimas filas del DataFrame:
#                    business_id                      name  \
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                        address          city state postal_code   latitude  \
# 150341       3388 Gateway Blvd      Edmonton    IN     T6J 5H2  53.468419
# 150342      2813 Bransford Ave     Nashville    DE       37204  36.115118
# 150343  6020 E 82nd St, Ste 46  Indianapolis    AB       46250  39.908707
# 150344            2472 Troy Rd  Edwardsville    AB       62025  38.782351
# 150345   238 Apollo Beach Blvd  Apollo beach    TN       33572  27.771002
#
#          longitude stars review_count  ... state postal_code latitude  \
# 150341 -113.492054   3.0           13  ...   NaN         NaN      NaN
# 150342  -86.766925   4.0            5  ...   NaN         NaN      NaN
# 150343  -86.065088   3.5            8  ...   NaN         NaN      NaN
# 150344  -89.950558   4.0           24  ...   NaN         NaN      NaN
# 150345   -82.39491   4.5            9  ...   NaN         NaN      NaN
#
#        longitude stars review_count is_open attributes categories hours
# 150341       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 150342       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 150343       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 150344       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 150345       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [5 rows x 28 columns]

# %%
# Eliminar columnas duplicadas por nombre
df_businees= df_businees.loc[:, ~df_businees.columns.duplicated()]

# %% [markdown]
# verificar nulos o faltantes y eliminar o modificar segun sea conveniemte

# %%
# Verificar la cantidad de valores nulos por columna
df_businees.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               3
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %%
# Porcentaje de valores nulos por columna
(df_businees.isnull().mean() * 100)
# Out:
# business_id      0.000000
# name             0.000000
# address          0.000000
# city             0.000000
# state            0.001995
# postal_code      0.000000
# latitude         0.000000
# longitude        0.000000
# stars            0.000000
# review_count     0.000000
# is_open          0.000000
# attributes       9.141580
# categories       0.068509
# hours           15.446370
# dtype: float64

# %% [markdown]
# modificacion de tipo de datos

# %%
# Convertir las columnas específicas a tipo 'string'
columnas_string = ['business_id', 'name', 'address', 'city', 'state', 'postal_code']

# Convertir las columnas seleccionadas a tipo string
df_businees[columnas_string] = df_businees[columnas_string].astype('string')

# Verificar las columnas de tipo string después de la conversión
print(df_businees.select_dtypes(include=['string']).columns)
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code'], dtype='object')

# %%
# Lista de columnas que deberían ser numéricas
columnas_numericas = ['stars', 'review_count', 'latitude', 'longitude','is_open']  # Ajusta los nombres de las columnas según tu DataFrame

# Convertir todas las columnas mencionadas a tipo numérico
for columna in columnas_numericas:
    df_businees[columna] = pd.to_numeric(df_businees[columna], errors='coerce')

# Verificar si las columnas se han convertido correctamente a numéricas
print(df_businees.select_dtypes(include=[np.number]).columns)
# Out:
# Index(['latitude', 'longitude', 'stars', 'review_count', 'is_open'], dtype='object')

# %%
# Convertir 'attributes' de diccionario a cadena de texto (clave: valor)
df_businees['attributes'] = df_businees['attributes'].apply(lambda x: str(x) if isinstance(x, dict) else x)

# Convertir 'categories' de lista a cadena de texto separada por comas
df_businees['categories'] = df_businees['categories'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# Convertir 'hours' de diccionario a cadena de texto (formato 'key: value')
df_businees['hours'] = df_businees['hours'].apply(lambda x: str(x) if isinstance(x, dict) else x)

# Verificar los cambios en las columnas
print(df_businees[['attributes', 'categories', 'hours']].head())
# Out:
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
# Verificar los tipos de datos después de la conversión
print(df_businees.dtypes)
# Out:
# business_id     string[python]
# name            string[python]
# address         string[python]
# city            string[python]
# state           string[python]
# postal_code     string[python]
# latitude               float64
# longitude              float64
# stars                  float64
# review_count             int64
# is_open                  int64
# attributes              object
# categories              object
# hours                   object
# dtype: object

# %% [markdown]
# estadisticas y visualizacion de valores atipicos

# %%
# Estadísticas descriptivas para columnas numéricas
df_businees.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  150346.000000  150346.000000  150346.000000  150346.000000
# mean       36.671150     -89.357339       3.596724      44.866561
# std         5.872759      14.918502       0.974421     121.120136
# min        27.555127    -120.095137       1.000000       5.000000
# 25%        32.187293     -90.357810       3.000000       8.000000
# 50%        38.777413     -86.121179       3.500000      15.000000
# 75%        39.954036     -75.421542       4.500000      37.000000
# max        53.679197     -73.200457       5.000000    7568.000000
#
#             is_open
# count  150346.00000
# mean        0.79615
# std         0.40286
# min         0.00000
# 25%         1.00000
# 50%         1.00000
# 75%         1.00000
# max         1.00000

# %% [markdown]
# Stars (Calificación):
#  * Promedio: La calificación promedio de los negocios es de 3.59 estrellas, lo que sugiere que la mayoría de los negocios tienen una calificación decente, aunque no sobresaliente.
#  * Distribución: La desviación estándar de 0.97 indica que las calificaciones están relativamente dispersas alrededor de la media. Hay negocios con calificaciones desde 1 estrella (mínimo) hasta 5 estrellas (máximo).
#  * Mediana: La mediana de 3.5 estrellas es muy cercana al promedio, lo que refuerza la idea de que la distribución de calificaciones es bastante simétrica.
# Review_count (Cantidad de Reseñas):
#  * Promedio: En promedio, los negocios tienen alrededor de 44.87 reseñas.
#  * Dispersión: La desviación estándar es muy alta (121.12), lo que indica una gran variabilidad en la cantidad de reseñas. Algunos negocios tienen muy pocas reseñas, mientras que otros tienen cientos o incluso miles.
#  * Valores Extremos: El valor máximo de 7568 reseñas sugiere que hay negocios muy populares con una gran cantidad de opiniones

# %%
# Calculamos el Z-score para las columnas numéricas
z_scores = np.abs(zscore(df_businees.select_dtypes(include=[np.number])))

# Identificamos los outliers. Se consideran outliers aquellos con Z-score > 3
outliers_zscore = np.where(z_scores > 3)

# Mostrar los índices de los outliers detectados
print("\nOutliers identificados usando el método Z-score:")
print(outliers_zscore)

# Mostrar los valores atípicos en el DataFrame
outliers_data = df_businees.iloc[outliers_zscore[0]]
print("\nValores atípicos en el DataFrame:")
print(outliers_data)
# Out:
# Outliers identificados usando el método Z-score:
# (array([    89,    112,    141, ..., 150249, 150285, 150323], shape=(1942,)), array([3, 3, 3, ..., 3, 3, 3], shape=(1942,)))
#
# Valores atípicos en el DataFrame:
#                    business_id                                         name  \
# 89      oaboaRBUgGjbo2kfUIKDLQ                             Mike's Ice Cream
# 112     sB45WFgysT617bKWP_WJwA                 Budweiser Brewery Experience
# 141     SZU9c8V2GuREDN5KgyHFJw              Santa Barbara Shellfish Company
# 181     ORL4JE6tz3rJxVqkdKfegA  Gaylord Opryland Resort & Convention Center
# 319     f82dhKNiUXsDVPMLqKYiIQ                                Sher-e-Punjab
# ...                        ...                                          ...
# 150214  2xxkaRy7rP5EUyjFt2J5kA                                  Nikka Ramen
# 150235  mzTTdvQGkUHZ8ii7OnZC5w                                 Trader Joe's
# 150249  8MzF1Tlgz0pOkxmhP5dYzA                            El Cap Restaurant
# 150285  fWeWzB9STxcX40AgSEQVcw                 Arizona-Sonora Desert Museum
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg                         Bittercreek Alehouse
#
#                   address            city state postal_code   latitude  \
# 89          129 2nd Ave N       Nashville    IL       37201  36.162649
# 112         1200 Lynch St     Saint Louis    PA       63118  38.600197
# 141     230 Stearns Wharf   Santa Barbara    TN       93101  34.408715
# 181      2800 Opryland Dr       Nashville    NV       37214  36.211592
# 319     853 East Grant Rd          Tucson    TN       85719  32.250960
# ...                   ...             ...   ...         ...        ...
# 150214    5701 Calle Real          Goleta    FL       93117  34.440885
# 150235     2121 Market St    Philadelphia    FL       19103  39.954178
# 150249      3500 4th St N  St. Petersburg    FL       33704  27.804140
# 150285   2021 N Kinney Rd          Tucson    NJ       85743  32.243733
# 150323       246 N 8th St           Boise    PA       83702  43.616590
#
#          longitude  stars  review_count  is_open  \
# 89      -86.775973    4.5           593        1
# 112     -90.213538    4.5           605        1
# 141    -119.685019    4.0          2404        1
# 181     -86.694319    3.0          1639        1
# 319    -110.959158    4.0           446        1
# ...            ...    ...           ...      ...
# 150214 -119.823523    4.5           562        1
# 150235  -75.175980    4.0           494        1
# 150249  -82.638855    3.5           414        1
# 150285 -111.166815    4.5           448        1
# 150323 -116.202383    4.5           998        1
#
#                                                attributes  \
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 112     {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 141     {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 181     {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 319     {'RestaurantsAttire': "'casual'", 'BusinessAcc...
# ...                                                   ...
# 150214  {'ByAppointmentOnly': 'False', 'Alcohol': "u'b...
# 150235  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 150249  {'GoodForKids': 'True', 'BikeParking': 'True',...
# 150285  {'GoodForKids': 'True', 'BusinessParking': "{'...
# 150323  {'BikeParking': 'True', 'Alcohol': "u'full_bar...
#
#                                                categories  \
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 112     Bars, Beer Gardens, Food, Breweries, Nightlife...
# 141     Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 181     Venues & Event Spaces, Performing Arts, Arts &...
# 319     Restaurants, Salad, Pakistani, Indian, Cocktai...
# ...                                                   ...
# 150214                       Restaurants, Japanese, Ramen
# 150235  Beer, Wine & Spirits, Shopping, Grocery, Flori...
# 150249       American (Traditional), Burgers, Restaurants
# 150285  Parks, Zoos, Active Life, Botanical Gardens, M...
# 150323  Bars, Gastropubs, Sandwiches, Nightlife, Resta...
#
#                                                     hours
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 112     {'Monday': '0:0-0:0', 'Tuesday': '9:0-17:0', '...
# 141     {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 181     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 319     {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# ...                                                   ...
# 150214  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...
# 150235  {'Monday': '0:0-0:0', 'Tuesday': '9:0-19:0', '...
# 150249  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 150285  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 150323  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
#
# [1942 rows x 14 columns]

# %%
# Calcular el rango intercuartílico (IQR) para 'stars'
Q1_stars = df_businees["stars"].quantile(0.25)
Q3_stars = df_businees["stars"].quantile(0.75)
IQR_stars = Q3_stars - Q1_stars

# Definir los límites para detectar outliers en 'stars'
lower_bound_stars = Q1_stars - 1.5 * IQR_stars
upper_bound_stars = Q3_stars + 1.5 * IQR_stars

# Filtrar los valores atípicos en 'stars'
outliers_stars = df_businees[(df_businees["stars"] < lower_bound_stars) | (df_businees["stars"] > upper_bound_stars)]

# Mostrar los valores atípicos detectados en 'stars'
print("Valores atípicos en 'stars':")
print(outliers_stars)
# Out:
# Valores atípicos en 'stars':
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
# Calcular el rango intercuartílico (IQR) para 'review_count'
Q1_review_count = df_businees["review_count"].quantile(0.25)
Q3_review_count = df_businees["review_count"].quantile(0.75)
IQR_review_count = Q3_review_count - Q1_review_count

# Definir los límites para detectar outliers en 'review_count'
lower_bound_review_count = Q1_review_count - 1.5 * IQR_review_count
upper_bound_review_count = Q3_review_count + 1.5 * IQR_review_count

# Filtrar los valores atípicos en 'review_count'
outliers_review_count = df_businees[(df_businees["review_count"] < lower_bound_review_count) | (df_businees["review_count"] > upper_bound_review_count)]

# Mostrar los valores atípicos detectados en 'review_count'
print("Valores atípicos en 'review_count':")
print(outliers_review_count)
# Out:
# Valores atípicos en 'review_count':
#                    business_id                          name  \
# 14      0bPLkL0QhhPO5kt1_EXmNQ          Zio's Italian Market
# 15      MUTTqe8uqyMdBl186RmNeA                      Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                           BAP
# 23      9OG5YkX1g2GReZM0AskizA       Romano's Macaroni Grill
# 27      tMkwHmWFUEXrC9ZduonpTg            The Green Pheasant
# ...                        ...                           ...
# 150285  fWeWzB9STxcX40AgSEQVcw  Arizona-Sonora Desert Museum
# 150290  uriD7RFuHhLJeDdKaf0nFA                    Pizza Guru
# 150296  lCo7sEuxlfFeT-nAOR-sbA                   Apple Store
# 150322  2MAQeAqmD8enCT2ZYqUgIQ   The Melting Pot - Nashville
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg          Bittercreek Alehouse
#
#                             address           city state postal_code  \
# 14                    2575 E Bay Dr          Largo    FL       33771
# 15                      205 Race St   Philadelphia    IN       19106
# 19                    1224 South St   Philadelphia    AZ       19147
# 23               5505 S Virginia St           Reno    AB       89502
# 27                    215 1st Ave S      Nashville    TN       37201
# ...                             ...            ...   ...         ...
# 150285             2021 N Kinney Rd         Tucson    NJ       85743
# 150290                3534 State St  Santa Barbara    PA       93105
# 150296  3301 Veterans Memorial Blvd       Metairie    NV       70002
# 150322         166 2nd Ave N, Ste A      Nashville    PA       37201
# 150323                 246 N 8th St          Boise    PA       83702
#
#          latitude   longitude  stars  review_count  is_open  \
# 14      27.916116  -82.760461    4.5           100        0
# 15      39.953949  -75.143226    4.0           245        1
# 19      39.943223  -75.162568    4.5           205        1
# 23      39.476117 -119.789339    2.5           339        1
# 27      36.159886  -86.773197    4.0           161        0
# ...           ...         ...    ...           ...      ...
# 150285  32.243733 -111.166815    4.5           448        1
# 150290  34.440689 -119.739681    4.0           299        0
# 150296  30.005648  -90.157396    3.0           142        1
# 150322  36.163875  -86.776311    4.0           204        0
# 150323  43.616590 -116.202383    4.5           998        1
#
#                                                attributes  \
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 15      {'RestaurantsReservations': 'True', 'Restauran...
# 19      {'NoiseLevel': "u'quiet'", 'GoodForMeal': "{'d...
# 23      {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 27      {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# ...                                                   ...
# 150285  {'GoodForKids': 'True', 'BusinessParking': "{'...
# 150290  {'NoiseLevel': "u'average'", 'RestaurantsGoodF...
# 150296  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
# 150323  {'BikeParking': 'True', 'Alcohol': "u'full_bar...
#
#                                                categories  \
# 14            Food, Delis, Italian, Bakeries, Restaurants
# 15                      Sushi Bars, Restaurants, Japanese
# 19                                    Korean, Restaurants
# 23                                   Restaurants, Italian
# 27                         Restaurants, Japanese, Seafood
# ...                                                   ...
# 150285  Parks, Zoos, Active Life, Botanical Gardens, M...
# 150290                           Restaurants, Pizza, Food
# 150296  IT Services & Computer Repair, Mobile Phones, ...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
# 150323  Bars, Gastropubs, Sandwiches, Nightlife, Resta...
#
#                                                     hours
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 15      {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 19      {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 23      {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 27      {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150285  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 150290  {'Monday': '15:0-21:0', 'Tuesday': '15:0-21:0'...
# 150296  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
# 150323  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
#
# [18302 rows x 14 columns]

# %%
# Visualizar boxplot para las columnas 'stars' y 'review_count'
columnas_a_graficar = ['stars', 'review_count']  # Especificamos las columnas que queremos graficar

for columna in columnas_a_graficar:
    if columna in df_businees.columns:  # Aseguramos que la columna exista en el DataFrame
        plt.figure(figsize=(6, 4))
        sns.boxplot(x=df_businees[columna])
        plt.title(f"Boxplot de la columna {columna}")
        plt.show()
    else:
        print(f"La columna '{columna}' no está presente en el DataFrame.")

# %% [markdown]
# boxplot de columnas review_count:
# *Distribución Asimétrica: La caja del boxplot está muy comprimida hacia la izquierda, lo que indica que la distribución de "review_count" está fuertemente sesgada hacia valores bajos. Esto significa que la mayoría de los negocios tienen un número relativamente pequeño de reseñas.
# Presencia de Outliers: Se observan numerosos puntos individuales (outliers) a la derecha del boxplot, extendiéndose hasta valores muy altos de "review_count". Estos outliers representan negocios con un número excepcionalmente grande de reseñas en comparación con la mayoría.
# *Mediana Baja: La línea dentro de la caja (que representa la mediana) está ubicada cerca del extremo izquierdo de la caja. Esto refuerza la idea de que la mayoría de los negocios tienen un número bajo de reseñas.
# *Rango Intercuartílico (IQR) Pequeño: La caja del boxplot, que representa el IQR (el rango entre el percentil 25 y el percentil 75), es relativamente pequeña. Esto sugiere que la mayoría de los negocios tienen un número de reseñas que no varía mucho entre sí, pero hay algunos que se disparan.

# %% [markdown]
# Boxplot de colunna"stars":
#  * Rango de Calificaciones: La caja del boxplot se extiende desde aproximadamente 3.0 hasta 4.5 en el eje de "stars". Esto indica que la mayoría de los negocios en el conjunto de datos tienen calificaciones entre 3.0 y 4.5 estrellas.
#  * Mediana: La línea dentro de la caja (que representa la mediana) está ubicada cerca de 3.75. Esto sugiere que el valor central de las calificaciones de los negocios está alrededor de 3.75 estrellas.
#  * Distribución Relativamente Simétrica: La caja del boxplot parece ser relativamente simétrica, lo que indica que la distribución de las calificaciones es bastante uniforme alrededor de la mediana.
#  * Ausencia de Outliers Significativos: No se observan outliers significativos en el boxplot. Esto sugiere que no hay negocios con calificaciones extremadamente altas o bajas en comparación con la mayoría.

# %%
import matplotlib.pyplot as plt

# Seleccionar las columnas 'stars' y 'review_count'
df_businees[['stars', 'review_count']].hist(bins=20, figsize=(8, 4))

# Ajustar la disposición del gráfico
plt.tight_layout()

# Mostrar los histogramas
plt.show()

# %% [markdown]
# Histograma de "stars":
#  * Distribución Asimétrica a la Izquierda: El histograma de "stars" muestra una distribución asimétrica a la izquierda (sesgada a la derecha). Esto significa que la mayoría de los negocios tienen calificaciones altas (entre 3 y 5 estrellas), mientras que hay relativamente pocos negocios con calificaciones bajas (1 y 2 estrellas).
#  * Pico en 4 Estrellas: El pico más alto del histograma se encuentra en 4 estrellas, lo que indica que esta es la calificación más común entre los negocios en el conjunto de datos.
#  * Baja Frecuencia de Calificaciones Bajas: La frecuencia de negocios con calificaciones de 1 y 2 estrellas es significativamente menor en comparación con las calificaciones más altas.
# Histograma de "review_count":
#  * Distribución Extremadamente Asimétrica a la Derecha: El histograma de "review_count" muestra una distribución extremadamente asimétrica a la derecha (sesgada a la izquierda). Esto significa que la gran mayoría de los negocios tienen un número muy bajo de reseñas, mientras que hay algunos negocios con un número excepcionalmente alto de reseñas.
#  * Pico en Valores Cercanos a Cero: El pico más alto del histograma se encuentra en valores cercanos a cero, lo que indica que la mayoría de los negocios tienen muy pocas reseñas.
#  * Cola Larga: La cola larga del histograma se extiende hasta valores muy altos de "review_count", lo que indica la presencia de outliers o negocios con un número excepcionalmente alto de reseñas.
#  Conclusiones Conjuntas:
#  * Calificaciones Altas Predominantes: La mayoría de los negocios en el conjunto de datos tienen calificaciones altas (3 a 5 estrellas), lo que sugiere que los clientes tienden a estar satisfechos con los negocios en general.
#  * Número de Reseñas Variable: El número de reseñas varía enormemente entre los negocios. La mayoría de los negocios tienen muy pocas reseñas, mientras que algunos tienen un número excepcionalmente alto.
#  * Posible Influencia del Número de Reseñas en las Calificaciones: Sería interesante investigar si existe una relación entre el número de reseñas y las calificaciones. ¿Los negocios con más reseñas tienden a tener calificaciones más altas?

# %%
# Eliminar filas con 'NaN' en la columna 'categories'
df_businees = df_businees.dropna(subset=['categories'])

# Convertir las cadenas separadas por comas en listas
df_businees['categories'] = df_businees['categories'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# Expansión de la columna 'categories' que es una lista
categories_expanded = df_businees['categories'].explode()  # Convertir cada lista en filas separadas

# Contamos la frecuencia de cada categoría
category_counts = categories_expanded.value_counts()

# Limitar el número de categorías a las 10 más frecuentes
category_counts_top_10 = category_counts.head(10)

# Visualizamos los resultados con un gráfico de barras
plt.figure(figsize=(8, 4))
sns.barplot(x=category_counts_top_10.index, y=category_counts_top_10.values)
plt.title('Top 10 Frecuencia de Categorías de Negocios')
plt.xlabel('Categoría')
plt.ylabel('Número de Negocios')
plt.xticks(rotation=90)  # Rota las etiquetas del eje X para mejor visualización
plt.show()

# %% [markdown]
# Dominio de Restaurantes: La categoría "Restaurants" es la más frecuente, con un número significativamente mayor de negocios en comparación con las demás categorías. Esto indica que los restaurantes son una parte importante del conjunto de datos.
# Presencia de Negocios Relacionados con la Comida: Las categorías "Food" y "Restaurants" son las dos más frecuentes, lo que sugiere que los negocios relacionados con la comida son muy comunes en el conjunto de datos.
# Diversidad de Categorías: El gráfico muestra una variedad de categorías de negocios, desde servicios locales y para el hogar hasta belleza y spas, salud y medicina, compras, vida nocturna, bares y automoción. Esto indica que el conjunto de datos cubre una amplia gama de tipos de negocios.
# Disminución Gradual de la Frecuencia: La frecuencia de las categorías disminuye gradualmente a medida que avanzamos de izquierda a derecha en el gráfico. Esto sugiere que hay una jerarquía en la frecuencia de las categorías, con algunas categorías siendo mucho más comunes que otras.

# %%
# Seleccionamos solo las columnas 'stars' y 'review_count'
df_subset = df_businees[['stars', 'review_count']]

# Calculamos la matriz de correlación entre 'stars' y 'review_count'
correlation_matrix = df_subset.corr()

# Visualizamos la matriz de correlación con un mapa de calor
plt.figure(figsize=(6, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriz de Correlación entre "stars" y "review_count"')
plt.show()

# %% [markdown]
# La matriz de correlación muestra que no hay una relación lineal fuerte entre las calificaciones de los negocios y el número de reseñas que reciben. La correlación de 0.06 sugiere que las dos variables son prácticamente independientes entre sí. Sin embargo, esto no descarta la posibilidad de relaciones no lineales o la influencia de otros factores

# %%
# Gráfico de dispersión para observar la relación entre 'review_count' y 'stars'
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_businees, x='review_count', y='stars')
plt.title('Relación entre el número de reseñas y la calificación')
plt.xlabel('Número de Reseñas (review_count)')
plt.ylabel('Calificación (stars)')
plt.show()

# Calcular la correlación de Pearson entre 'review_count' y 'stars'
correlacion = df_businees['review_count'].corr(df_businees['stars'])

print(f"Correlación de Pearson entre 'review_count' y 'stars': {correlacion}")

# Si la correlación es baja, se puede verificar la relación usando una regresión lineal simple:
import numpy as np
from sklearn.linear_model import LinearRegression

# Reshape para que sea compatible con el modelo de regresión
X = df_businees['review_count'].values.reshape(-1, 1)  # Número de reseñas
y = df_businees['stars'].values  # Calificación

# Crear el modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(X, y)

# Predicciones del modelo
predicciones = modelo.predict(X)

# Graficar la regresión lineal
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_businees, x='review_count', y='stars', label='Datos reales')
plt.plot(df_businees['review_count'], predicciones, color='red', label='Regresión lineal')
plt.title('Regresión lineal entre número de reseñas y calificación')
plt.xlabel('Número de Reseñas (review_count)')
plt.ylabel('Calificación (stars)')
plt.legend()
plt.show()
# Out:
# Correlación de Pearson entre 'review_count' y 'stars': 0.05964636979419793

# %% [markdown]
# El gráfico de dispersión muestra que no hay una relación lineal fuerte entre el número de reseñas y la calificación de los negocios. La mayoría de los negocios tienen calificaciones altas, independientemente del número de reseñas. Esto sugiere que otros factores, además del número de reseñas, juegan un papel importante en la determinación de las calificaciones.

# %% [markdown]
# El gráfico de regresión lineal muestra que no hay una relación lineal fuerte entre el número de reseñas y la calificación de los negocios. La línea de regresión lineal no se ajusta bien a los datos, lo que sugiere que un modelo lineal no es adecuado para modelar esta relación. Esto indica que otros factores, además del número de reseñas, juegan un papel importante en la determinación de las calificaciones

# %%
df_businees.to_pickle(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\business_modificado.pkl")

# %% [markdown]
# CONCLUSION FINAL :Calificaciones Altas Predominantes: La mayoría de los negocios en el conjunto de datos tienen calificaciones altas (entre 3 y 5 estrellas), lo que sugiere que los clientes están generalmente satisfechos con los negocios.
#
# Número de Reseñas Variable: El número de reseñas varía enormemente entre los negocios, con la mayoría de los negocios teniendo pocas reseñas y unos pocos con una cantidad excepcionalmente alta.
#
#
# Categorías de Negocios:
# Dominio de Restaurantes: La categoría más frecuente es "Restaurants", con un número significativamente mayor de negocios en comparación con otras categorías. Esto indica que los restaurantes son una parte importante del conjunto de datos.
#
# Presencia de Negocios Relacionados con la Comida: Las categorías "Food" y "Restaurants" son las dos más frecuentes, lo que indica que los negocios relacionados con la comida son comunes en el conjunto de datos.
#
# Diversidad de Categorías: El gráfico muestra una variedad de categorías de negocios, desde servicios locales y para el hogar hasta belleza y spas, salud y medicina, compras, vida nocturna, bares y automoción. Esto sugiere que el conjunto de datos cubre una amplia gama de tipos de negocios.
#
# Disminución Gradual de la Frecuencia: La frecuencia de las categorías disminuye gradualmente a medida que avanzamos de izquierda a derecha en el gráfico. Esto sugiere que hay algunas categorías dominantes y otras menos representadas.
#
# Matriz de Correlación:
# Baja Correlación entre Calificaciones y Reseñas: La matriz de correlación muestra que no hay una relación lineal fuerte entre las calificaciones (stars) y el número de reseñas (review_count), con un valor de correlación de 0.06. Esto indica que las dos variables son prácticamente independientes entre sí.
#
# Posibles Relaciones No Lineales o Influencia de Otros Factores: Aunque no hay una correlación lineal fuerte, esto no descarta la posibilidad de que existan relaciones no lineales o que otros factores, no considerados en el análisis, puedan influir en estas variables.

# %% [markdown]
# EDA CKECKIN

# %%
# Cargar el archivo checkin.json con lines=True
df_checkins = pd.read_json(r"C:/Users/yanin/OneDrive/Desktop/proyecto final/archivos/yelp/checkin.json", lines=True)

# Ver las primeras filas del DataFrame para asegurarnos de que está correctamente cargado
df_checkins.head()
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...

# %%
# Verificar los valores faltantes/nulos en cada columna
print("Valores nulos por columna:")
print(df_checkins.isnull().sum())

# Verificar las filas duplicadas
print("\nNúmero de filas duplicadas:")
print(df_checkins.duplicated().sum())

# Ver un resumen general de los datos faltantes y duplicados
print("\nResumen de los datos:")
summary = {
    "Total filas": df_checkins.shape[0],
    "Total columnas": df_checkins.shape[1],
    "Filas con valores nulos": df_checkins.isnull().any(axis=1).sum(),
    "Total valores nulos": df_checkins.isnull().sum().sum(),
    "Filas duplicadas": df_checkins.duplicated().sum(),
    "Filas únicas": df_checkins.drop_duplicates().shape[0]
}

for key, value in summary.items():
    print(f"{key}: {value}")
# Out:
# Valores nulos por columna:
# business_id    0
# date           0
# dtype: int64
#
# Número de filas duplicadas:
# 0
#
# Resumen de los datos:
# Total filas: 131930
# Total columnas: 2
# Filas con valores nulos: 0
# Total valores nulos: 0
# Filas duplicadas: 0
# Filas únicas: 131930

# %%
# Definir el tamaño de cada fragmento
chunk_size = 100000  # Por ejemplo, 100,000 filas por vez

# Lista para almacenar los fragmentos procesados
chunk_list = []

# Leer los datos en fragmentos, asegurándose de que cada línea sea un JSON independiente
for chunk in pd.read_json(r"C:/Users/yanin/OneDrive/Desktop/proyecto final/archivos/yelp/checkin.json", lines=True, chunksize=chunk_size):
    # Dividir las fechas por coma
    chunk['date'] = chunk['date'].str.split(', ')
    
    # Expandir las fechas
    chunk_expanded = chunk.explode('date')
    
    # Convertir las fechas a datetime
    chunk_expanded['date'] = pd.to_datetime(chunk_expanded['date'])
    
    # Agregar el fragmento procesado a la lista
    chunk_list.append(chunk_expanded)

# Concatenar todos los fragmentos procesados en un solo DataFrame
df_checkins_expanded = pd.concat(chunk_list, ignore_index=True)

# Mostrar las primeras filas del DataFrame procesado
df_checkins_expanded.head()
# Out:
#               business_id                date
# 0  ---kPU91CF4Lq2-WlRu9Lw 2020-03-13 21:10:56
# 1  ---kPU91CF4Lq2-WlRu9Lw 2020-06-02 22:18:06
# 2  ---kPU91CF4Lq2-WlRu9Lw 2020-07-24 22:42:27
# 3  ---kPU91CF4Lq2-WlRu9Lw 2020-10-24 21:36:13
# 4  ---kPU91CF4Lq2-WlRu9Lw 2020-12-09 21:23:33

# %%
# Contar la cantidad de check-ins por negocio
checkins_per_business = df_checkins_expanded.groupby('business_id').size().reset_index(name='checkin_count')

# Mostrar los primeros negocios con más check-ins
checkins_per_business.sort_values(by='checkin_count', ascending=False).head()
# Out:
#                   business_id  checkin_count
# 878    -QI8Qi8XWH3D8y8ethnajA          52144
# 33681  FEXhWNCMkv22qG04E83Qjg          40109
# 32401  Eb1XmmLWyt_way5NNZ7-Pw          37562
# 83440  c_4c5rJECZSfNgFj7frwHQ          37518
# 11840  4i4kmYm9wgSNyF1b6gKphg          31168

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizar la distribución de los check-ins por negocio
plt.figure(figsize=(10,5))
sns.barplot(x='checkin_count', y='business_id', data=checkins_per_business.sort_values(by='checkin_count', ascending=False).head(20), palette='viridis')
plt.title('Top 20 Negocios con Más Check-ins')
plt.xlabel('Número de Check-ins')
plt.ylabel('ID de Negocio')
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\1530366447.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='checkin_count', y='business_id', data=checkins_per_business.sort_values(by='checkin_count', ascending=False).head(20), palette='viridis')

# %% [markdown]
# El gráfico permite identificar rápidamente los negocios con el mayor número de check-ins. Los negocios en la parte superior del gráfico tienen barras más largas, lo que indica un mayor número de visitas registradas. La gradación de color también ayuda a visualizar la distribución de los check-ins entre los diferentes negocios.

# %%
# Imprimir las primeras filas del DataFrame y las columnas para verificar la columna correcta
print(df_checkins_expanded.head())
print(df_checkins_expanded.columns)
# Out:
#               business_id                date
# 0  ---kPU91CF4Lq2-WlRu9Lw 2020-03-13 21:10:56
# 1  ---kPU91CF4Lq2-WlRu9Lw 2020-06-02 22:18:06
# 2  ---kPU91CF4Lq2-WlRu9Lw 2020-07-24 22:42:27
# 3  ---kPU91CF4Lq2-WlRu9Lw 2020-10-24 21:36:13
# 4  ---kPU91CF4Lq2-WlRu9Lw 2020-12-09 21:23:33
# Index(['business_id', 'date'], dtype='object')

# %%
# Convertir la columna a tipo datetime si no lo está
df_checkins_expanded['date'] = pd.to_datetime(df_checkins_expanded['date'])

# Extraer el día de la semana
df_checkins_expanded['day_of_week'] = df_checkins_expanded['date'].dt.dayofweek
# Contar los check-ins por día de la semana
checkins_by_day = df_checkins_expanded.groupby('day_of_week').size().reset_index(name='checkin_count')

# Mapear los números de los días a nombres de días de la semana
checkins_by_day['day_of_week'] = checkins_by_day['day_of_week'].map({
    0: 'Lunes', 1: 'Martes', 2: 'Miércoles', 3: 'Jueves', 4: 'Viernes', 5: 'Sábado', 6: 'Domingo'
})

# Visualizar la distribución de check-ins por día de la semana
plt.figure(figsize=(10, 6))
sns.barplot(x='day_of_week', y='checkin_count', data=checkins_by_day, palette='Blues_d')
plt.title('Número de Check-ins por Día de la Semana')
plt.xlabel('Día de la Semana')
plt.ylabel('Número de Check-ins')
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\603912950.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day_of_week', y='checkin_count', data=checkins_by_day, palette='Blues_d')

# %% [markdown]
# El gráfico muestra claramente la distribución de los check-ins a lo largo de la semana. Se observa que los sábados y domingos tienen el mayor número de check-ins, seguidos de los viernes. Los días de semana (lunes a jueves) tienen un número de check-ins relativamente menor.

# %%
df_checkins_expanded['date'] = pd.to_datetime(df_checkins_expanded['date'])
df_checkins_expanded['hour_of_day'] = df_checkins_expanded['date'].dt.hour

# Extraer la hora del día de los check-ins
#df_checkins_expanded['hour_of_day'] = df_checkins_expanded['checkin_datetime'].dt.hour

# Contar los check-ins por hora del día
checkins_by_hour = df_checkins_expanded.groupby('hour_of_day').size().reset_index(name='checkin_count')

# Visualizar la distribución de check-ins por hora del día
plt.figure(figsize=(10, 6))
sns.lineplot(x='hour_of_day', y='checkin_count', data=checkins_by_hour, marker='o', color='green')
plt.title('Número de Check-ins por Hora del Día')
plt.xlabel('Hora del Día')
plt.ylabel('Número de Check-ins')
plt.grid(True)
plt.show()

# %% [markdown]
#  * Patrón Bimodal: El gráfico muestra un patrón bimodal en el número de check-ins a lo largo del día. Hay dos picos de actividad: uno temprano en la mañana (alrededor de las 0 horas) y otro por la tarde/noche (alrededor de las 16-17 horas).
#  * Baja Actividad en la Madrugada: El número de check-ins es significativamente bajo durante las horas de la madrugada (aproximadamente de las 2 a las 10 horas).
#  * Aumento Gradual por la Tarde: Después de la baja actividad en la madrugada, hay un aumento gradual en el número de check-ins a partir de las 10 horas, alcanzando el pico principal por la tarde/noche.
#  * Actividad Nocturna: Aunque el pico principal ocurre por la tarde, todavía se observa una cantidad considerable de check-ins durante la noche, aunque con una ligera disminución después del pico.
# Posibles Interpretaciones:
#  * Rutinas Diarias: El patrón bimodal podría reflejar las rutinas diarias de las personas. El pico de la mañana podría estar relacionado con actividades tempranas como ir al trabajo o hacer ejercicio, mientras que el pico de la tarde/noche podría estar relacionado con actividades sociales, cenas o salidas nocturnas.
#  * Tipos de Negocios: El patrón también podría estar influenciado por los tipos de negocios incluidos en el conjunto de datos. Por ejemplo, los gimnasios podrían contribuir al pico de la mañana, mientras que los restaurantes y bares podrían contribuir al pico de la tarde/noche.
#  * Comportamiento del Usuario: El gráfico proporciona información valiosa sobre el comportamiento del usuario en términos de check-ins a lo largo del día. Esta información podría ser útil para que las empresas comprendan cuándo es más probable que los clientes visiten sus establecimiento

# %%
# Cargar el archivo de negocios para obtener las calificaciones


df_business = pd.read_pickle(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\business_modificado.pkl")

# %%
df_business = df_business.drop_duplicates(subset=['business_id'])

# Fusionar los datos de check-ins con las calificaciones de los negocios
df_checkins_with_stars = pd.merge(checkins_per_business, df_business[['business_id', 'stars']], on='business_id')

# Visualizar la relación entre el número de check-ins y la calificación de los negocios
plt.figure(figsize=(10, 6))
sns.scatterplot(x='checkin_count', y='stars', data=df_checkins_with_stars, color='purple')
plt.title('Relación entre Check-ins y Calificación de Negocios')
plt.xlabel('Número de Check-ins')
plt.ylabel('Calificación del Negocio')
plt.show()

# %% [markdown]
# El gráfico muestra la distribución de los negocios en función de su número de check-ins y su calificación. Se observa que:
#  * No hay una correlación fuerte: No parece haber una correlación lineal clara entre el número de check-ins y la calificación de los negocios. Hay negocios con un alto número de check-ins que tienen calificaciones bajas, y viceversa.
#  * Mayor concentración en calificaciones altas: La mayoría de los negocios tienen calificaciones relativamente altas (por encima de 3.0).
#  * Distribución dispersa: Los puntos están bastante dispersos en el gráfico, lo que indica que la relación entre las dos variables no es muy fuerte.
#  Otros factores influyen: La calificación de un negocio puede estar influenciada por otros factores además del número de check-ins, como la calidad del servicio, el precio, la ubicación, etc.
#  * Popularidad no siempre es igual a calidad: Un negocio puede ser popular (tener muchos check-ins) sin necesariamente tener una alta calificación.
#  * Subjetividad de las calificaciones: Las calificaciones de los negocios pueden ser subjetivas y variar según las preferencias de los usuarios.

# %% [markdown]
# Conclusión General:
# El análisis de los check-ins a lo largo de la semana y del día revela patrones interesantes que podrían reflejar las rutinas y comportamientos de los usuarios:
#
# Distribución de Check-ins a lo largo de la Semana:
#
# Los sábados y domingos son los días con mayor actividad, seguidos de cerca por los viernes, lo que indica que los usuarios tienden a hacer más check-ins durante el fin de semana. Por otro lado, los días de semana (lunes a jueves) muestran una menor actividad, lo que podría estar relacionado con la rutina laboral o escolar.
#
# Patrón Bimodal en el Día:
#
# La distribución de check-ins a lo largo del día muestra un patrón bimodal con dos picos de actividad: uno temprano por la mañana (alrededor de las 0 horas) y otro por la tarde/noche (alrededor de las 16-17 horas). Este patrón podría reflejar las rutinas diarias de las personas, como actividades tempranas (trabajo, ejercicio) y actividades sociales (cenas, salidas nocturnas).
#
# Se observa una baja actividad en la madrugada (aproximadamente entre las 2 y 10 horas), lo cual es natural dado que las personas suelen descansar en ese período.
#
# Aumento gradual por la tarde: Después de la baja actividad de la madrugada, los check-ins aumentan de manera gradual a medida que avanza el día, alcanzando su punto máximo en la tarde/noche.
#
# No Correlación Fuerte entre Check-ins y Calificaciones:
#
# No hay una correlación clara entre el número de check-ins y las calificaciones de los negocios, ya que algunos negocios con muchos check-ins tienen calificaciones bajas, y otros con pocos check-ins tienen calificaciones altas. Esto sugiere que la popularidad no siempre refleja la calidad del negocio.
#
# La mayoría de los negocios tienen calificaciones relativamente altas (por encima de 3.0), lo que podría indicar que los negocios bien valorados tienden a atraer a más usuarios, aunque no siempre de manera proporcional.
#
# La dispersión de los puntos en el gráfico indica que otros factores además del número de check-ins pueden influir en las calificaciones, como la calidad del servicio, la ubicación o el precio, lo que resalta la subjetividad de las calificaciones de los usuarios.

# %% [markdown]
# EDA TIPS

# %% [markdown]
# Las colunnas son:user_id, business_id, text, date , compliment_count

# %%
# Cargar el archivo JSON en un DataFrame de pandas

df_tips = pd.read_json(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\tip.json", lines=True)

# %%
# Ver las primeras filas del archivo para una rápida inspección
print(df_tips.head())
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text                date  \
# 0                     Avengers time with the ladies. 2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2             It's open even when you think it isn't 2013-08-18 00:56:08
# 3                          Very decent fried chicken 2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch 2012-10-06 19:43:09
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# Verificar valores nulos en cada columna
df_tips.isnull().sum()
# Out:
# user_id             0
# business_id         0
# text                0
# date                0
# compliment_count    0
# dtype: int64

# %%
# Verificar si hay filas duplicadas
df_tips.duplicated().sum()
# Out:
# np.int64(67)

# %%
# Verificar el tipo de datos de cada columna
df_tips.dtypes
# Out:
# user_id                     object
# business_id                 object
# text                        object
# date                datetime64[ns]
# compliment_count             int64
# dtype: object

# %% [markdown]
# convertir los datoas en string

# %%
# Convertir las columnas 'user_id', 'business_id', y 'text' a tipo string
df_tips['user_id'] = df_tips['user_id'].astype('string')
df_tips['business_id'] = df_tips['business_id'].astype('string')
df_tips['text'] = df_tips['text'].astype('string')

# Verificar los tipos de datos después de la conversión
print(df_tips.dtypes)
# Out:
# user_id             string[python]
# business_id         string[python]
# text                string[python]
# date                datetime64[ns]
# compliment_count             int64
# dtype: object

# %%
# Consejos más populares (según los cumplidos)
top_tips = df_tips.sort_values('compliment_count', ascending=False).head(10)
print(top_tips[['text', 'compliment_count']])

# Consejos más recientes
recent_tips = df_tips.sort_values('date', ascending=False).head(10)
print(recent_tips[['text', 'date']])
# Out:
#                                                      text  compliment_count
# 543367  Experience Bern's by sitting at the bar too . ...                 6
# 711663            Brandon. Come here for your bbq.  Gush.                 6
# 85848      $8 drink menu, Velvet seats, and Dog friendly.                 5
# 244605  30 minute wait for our drink order is unaccept...                 5
# 545163  Sumo oranges are in season. (Jan.- Mar.) They ...                 5
# 176024  Found my next car here through Car Gurus! Grea...                 4
# 25307   One of the theaters refusing to show "Straight...                 4
# 267196  carts cost $1 here now!  Last time I visited, ...                 4
# 107070  Look at the stars people! I'd rather have a ro...                 4
# 203239  So sad. Hattie's has closed:(. Best wishes to ...                 4
#                                                      text                date
# 538797  Donation drop off hours (non-clothing items - ... 2022-01-19 20:38:55
# 741844  Great service and beautiful nails!! Love my na... 2022-01-19 19:20:35
# 901828  Amazing service!! I'm and out in no time! Beat... 2022-01-19 19:07:52
# 697249                             Went above and beyond! 2022-01-19 19:06:01
# 536750  Great local spot with delicious food and live ... 2022-01-19 18:46:08
# 353922                              Overpriced incredibly 2022-01-19 18:42:44
# 826026  Signature Breakfast
# Best birthday breakfast ever. 2022-01-19 17:40:43
# 877776  Amazing food and an attentive staff. Throughly... 2022-01-19 17:37:41
# 505905                        90% off of clearance items! 2022-01-19 17:33:53
# 541978                                 Viet-style flavor. 2022-01-19 17:16:57

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

# Concatenar todos los consejos en un solo texto
text = ' '.join(df_tips['text'].dropna())

# Crear la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=100).generate(text)

# Visualizar la nube de palabras
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Desactivar los ejes
plt.show()

# %% [markdown]
# El gráfico muestra las siguientes palabras destacadas:
#  * "place" (lugar): Esta palabra es una de las más grandes y destacadas, lo que indica que se menciona con frecuencia en las reseñas.
#  * "food" (comida): Otra palabra grande y destacada, lo que sugiere que la comida es un tema importante en las reseñas.
#  * "great" (genial): Esta palabra también es grande y destacada, lo que indica que muchos usuarios tienen una opinión positiva sobre el lugar.
#  * "service" (servicio): Esta palabra también es grande y destacada, lo que sugiere que el servicio es un aspecto importante para los usuarios.
#  * "love" (amo): Esta palabra también es grande y destacada, lo que indica que muchos usuarios expresan su amor por el lugar.
# Otras palabras relevantes:
#  * "delicious" (delicioso)
#  * "amazing" (increíble)
#  * "best" (mejor)
#  * "try" (probar)
#  * "happy hour"
#  * "open" (abierto)
#  * "closed" (cerrado)
# Posibles Interpretaciones:
#  * Experiencia positiva: La presencia de palabras como "great", "delicious", "amazing" y "love" sugiere que muchos usuarios tienen una experiencia positiva en el lugar.
#  * Importancia de la comida y el servicio: Las palabras "food" y "service" destacan la importancia de estos aspectos para los usuarios.
#  * Menciones de horarios: Las palabras "open" y "closed" indican que los usuarios mencionan los horarios del lugar.
#  * Recomendaciones: La palabra "try" sugiere que los usuarios recomiendan probar el lugar.
# Conclusión:
# El gráfico de nube de palabras proporciona una visión general de los temas y sentimientos más comunes expresados por los usuarios en sus reseñas. La presencia de palabras positivas y la importancia de la comida y el servicio sugieren que el lugar tiene una buena reputación entre los usuarios. Sin embargo, se necesitaría un análisis más profundo del texto para obtener una comprensión más completa de las opiniones de los usuarios.

# %% [markdown]
# fusionamos archivos para analizar la informacion

# %%
df_business = pd.read_pickle(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\business_modificado.pkl")
# Fusionar los datos de consejos con los negocios para obtener más información
df_tips_with_business = pd.merge(df_tips, df_business[['business_id', 'name']], on='business_id')
print(df_tips_with_business[['text', 'name']].head())
# Out:
#                                                 text  \
# 0                     Avengers time with the ladies.
# 1  They have lots of good deserts and tasty cuban...
# 2             It's open even when you think it isn't
# 3                          Very decent fried chicken
# 4             Appetizers.. platter special for lunch
#
#                           name
# 0     Century 20 El Con and XD
# 1    La Segunda Central Bakery
# 2  Sean Thorntons Public House
# 3           Wok Out Restaurant
# 4                 Siam Cuisine

# %%
# Contar el número de consejos por cada negocio
tip_counts = df_tips_with_business['name'].value_counts().head(10)

# Crear un gráfico de barras
plt.figure(figsize=(12, 6))
tip_counts.plot(kind='bar', color='skyblue')
plt.title('Top 10 Negocios con más Consejos')
plt.xlabel('Negocios')
plt.ylabel('Número de Consejos')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
#  * Popularidad de Starbucks: Starbucks es el negocio con el mayor número de check-ins, superando significativamente a todos los demás negocios en el gráfico. Esto indica que Starbucks es el negocio más popular o frecuentado de la lista.
#  * McDonald's en Segundo Lugar: McDonald's ocupa el segundo lugar en términos de número de check-ins, aunque con una diferencia considerable en comparación con Starbucks.
#  * Popularidad Relativa: Los demás negocios en el gráfico (Cafe Du Monde, Dunkin, Chick-fil-A, Chipotle Mexican Grill, Whole Foods Market, Panera Bread y Taco Bell) tienen un número de check-ins relativamente similar, aunque menor en comparación con Starbucks y McDonald's.

# %%
# Asegúrate de tener la columna 'stars' en df_business
df_tips_with_stars = pd.merge(df_tips_with_business, df_business[['business_id', 'stars']], on='business_id')

# Crear un gráfico de dispersión entre el número de consejos y la calificación
tip_counts_per_business = df_tips_with_stars.groupby('name')['text'].count()
plt.figure(figsize=(10, 6))
plt.scatter(tip_counts_per_business, df_tips_with_stars.groupby('name')['stars'].mean(), color='purple')
plt.title('Relación entre Consejos y Calificación de Negocios')
plt.xlabel('Número de Consejos')
plt.ylabel('Promedio de Calificación')
plt.show()

# %% [markdown]
# * No hay una correlación fuerte: No parece haber una correlación lineal clara entre el número de consejos y la calificación promedio de los negocios. Hay negocios con un alto número de consejos que tienen calificaciones bajas, y viceversa.
#  * Mayor concentración en calificaciones altas: La mayoría de los negocios tienen calificaciones relativamente altas (por encima de 3.0).
#  * Distribución dispersa: Los puntos están bastante dispersos en el gráfico, lo que indica que la relación entre las dos variables no es muy fuerte.
#  * Mayor concentración en el origen: Hay una gran concentración de puntos en el origen del gráfico (cerca de 0 consejos y calificaciones bajas). Esto sugiere que hay muchos negocios con pocos consejos y calificaciones bajas.
#  * Posibles valores atípicos: Algunos puntos en el gráfico pueden ser valores atípicos que afectan la interpretación general de la relación.

# %%
# Asegúrate de que la columna 'date' sea de tipo datetime
df_tips_with_business['date'] = pd.to_datetime(df_tips_with_business['date'])

# Contar consejos por fecha
tips_per_date = df_tips_with_business.groupby(df_tips_with_business['date'].dt.date).size()

# Crear un gráfico de línea
plt.figure(figsize=(12, 6))
tips_per_date.plot(kind='line', color='orange')
plt.title('Número de Consejos a lo Largo del Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Número de Consejos')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# El gráfico muestra la siguiente tendencia general:
#  * Bajo número inicial: En los primeros años (alrededor de 2010), el número de consejos es muy bajo, casi cercano a cero.
#  * Aumento gradual: A partir de 2011-2012, se observa un aumento gradual en el número de consejos.
#  * Picos y valles: La línea muestra varios picos y valles, lo que indica fluctuaciones en el número de consejos a lo largo del tiempo.
#  * Tendencia general al alza: A pesar de las fluctuaciones, la tendencia general es al alza, lo que indica un aumento en el número de consejos a lo largo del tiempo.
#  * Ligera disminución reciente: En los últimos años (alrededor de 2019-2020), se observa una ligera disminución en el número de consejos.

# %% [markdown]
# CONCLUSION :
# Tendencia general del número de consejos:
#
# Bajo número inicial: En los primeros años, cerca de 2010, el número de consejos es extremadamente bajo, lo que puede indicar una adopción temprana del sistema de reseñas pero con pocos usuarios participando.
#
# Aumento gradual: A partir de 2011-2012, se observa un aumento sostenido en el número de consejos, lo que sugiere una creciente popularidad y participación de los usuarios en la plataforma.
#
# Picos y valles: La fluctuación en los picos y valles refleja la variabilidad en el comportamiento de los usuarios a lo largo del tiempo, posiblemente influenciada por eventos o campañas específicas.
#
# Tendencia general al alza: Aunque hay fluctuaciones, la tendencia a largo plazo es positiva, lo que indica una aceptación creciente de la plataforma de reseñas.
#
# Ligera disminución reciente: En los años más recientes (alrededor de 2019-2020), se observa una ligera disminución, lo que podría estar relacionado con cambios en el comportamiento del usuario o la saturación del mercado de reseñas.
#
# Relación entre consejos y calificaciones:
#
# No correlación fuerte: No parece existir una correlación clara entre el número de consejos y la calificación promedio de los negocios. Esto sugiere que los negocios con muchos consejos no necesariamente tienen las mejores calificaciones, y viceversa.
#
# Mayor concentración en calificaciones altas: Aunque hay negocios con muchos consejos y calificaciones bajas, la mayoría de los negocios tienden a tener calificaciones altas (por encima de 3.0).
#
# Distribución dispersa: La relación entre los consejos y las calificaciones es bastante dispersa, lo que indica que otros factores, como la calidad del servicio o la popularidad, pueden influir más en las calificaciones que en la cantidad de reseñas.
#
# Mayor concentración en el origen: Hay una notable concentración de negocios con pocos consejos y calificaciones bajas en el origen del gráfico, sugiriendo que muchos negocios pueden tener poco feedback de los usuarios.
#
# Popularidad de los negocios:
#
# Starbucks y McDonald's: Starbucks es el negocio más popular con la mayor cantidad de consejos, seguido de McDonald's, lo que refleja su atractivo masivo. Los negocios como Cafe Du Monde, Dunkin, Chick-fil-A, y otros tienen menos consejos, pero siguen siendo populares en general.
#
# Patrón de popularidad: Los negocios con mayor número de check-ins tienden a ser cadenas grandes con un fuerte reconocimiento de marca.
#
# Análisis de la nube de palabras en las reseñas:
#
# Palabras positivas predominantes: Las palabras "great", "food", "service" y "love" destacan en la nube de palabras, lo que indica que los usuarios suelen asociar estas características con una experiencia positiva en los negocios.
#
# Enfoque en la comida y el servicio: La relevancia de términos como "delicious", "amazing", y "try" resalta la importancia de la calidad de la comida y el servicio en las experiencias de los clientes.
#
# Menciones de horarios: Las palabras "open" y "closed" sugieren que los usuarios también mencionan las horas de funcionamiento de los negocios.
#
# Recomendaciones: La palabra "try" indica que los usuarios a menudo recomiendan probar los lugares, lo que puede ser un factor clave para atraer nuevos clientes.

# %% [markdown]
# edad de "review.json"

# %% [markdown]
# las columna:
# review_id ,user_id, business_id, stars , useful, funny, cool, text, date.

# %%
chunks = pd.read_json(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\review.json", lines=True, chunksize=chunk_size)
for chunk in chunks:
    print(f"Procesando {len(chunk)} filas.")
    print(chunk.head())
# Out:
# Procesando 100000 filas.
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 100000  bwaSF4fYDBgyls0MBVcuOw  ZvmZM7LBzaYbpznpHlTANA
# 100001  nyAaYpT3zrFdzQEiI1lf_g  kdfnlAi3VPqAw64REgJh7w
# 100002  hOl6MoudNRyeK7iC8V_UvA  UMS5obm9Gwr7AyfvEJyhkw
# 100003  VnVU0FtwvQtOHcB9unmVtg  9a0US1vaEBiQlMl2j2vmrg
# 100004  vL2pkx9P-QS7PaPeufpaSg  a6xJIRlwDKmosaip9ZQ1OQ
#
#                    business_id  stars  useful  funny  cool  \
# 100000  lmgCjE_h9VkpJYjsD2Li0A      3       0      0     0
# 100001  EDjEVzmoQVHzboFqC-M6Ew      4       2      0     2
# 100002  fGYnHzFr1z2kv7bPRW6VMA      5       0      1     0
# 100003  7EhTT4iEuA7JaaWA-eI3Qw      5       1      0     1
# 100004  s_iBdCSstqS6oyc_gHezFQ      4       0      0     0
#
#                                                      text                date
# 100000  Why 3 stars?\n\nI love Target, but here is jus... 2018-05-02 12:31:05
# 100001  The Local Taco is the first joint I've found i... 2011-03-29 04:44:08
# 100002  Top notch! He will cater our wedding and  Fran... 2014-10-02 11:32:33
# 100003  Best place to get a vietnamese sandwich and bo... 2015-04-20 14:30:49
# 100004  This is more like a 3 1/2 star rating. The foo... 2012-07-21 23:02:43
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 200000  1IEzEH_J7TH21fKFdfxlNQ  345cM-IMsRDwutYG-AkJNw
# 200001  T2fSdeY5PiEWKpLuNfGuIQ  bpgKKIpdAmtqdzJT5X3xRw
# 200002  dVtQ7aQ0vp4VNL-BxN2XtQ  vq9TI11JinsJuRVXhJZ4gw
# 200003  6BxXel97olHZHv_o8F62pw  fEptE7AEC2GQqHJjfzh0qA
# 200004  _u5vDb3RLkIMZ4X1DCxRAg  NfjcPbXlhqVWBRPFL9vs3g
#
#                    business_id  stars  useful  funny  cool  \
# 200000  LHSTtnW3YHCeUkRDGyJOyw      5       6      0     3
# 200001  v5kwdvmg-J8g-ll0nkc3Sw      5       0      0     0
# 200002  gGCIGJcKWoPC9xZNDeX3pA      4       0      0     1
# 200003  F8yozE3NWnImNApHO347gQ      4       0      0     0
# 200004  pFnoqSPstZKsnyeNBIeuZg      5       1      0     0
#
#                                                      text                date
# 200000  Great craft beers, great fresh food.  Small me... 2015-04-12 00:20:02
# 200001  Establishments like The Libertine remind me th... 2013-05-23 18:27:42
# 200002  A sub is a sub is a sub, but not when it's Eeg... 2012-03-15 18:26:47
# 200003  I went for my birthday in oct. I had a large g... 2017-01-11 23:01:18
# 200004  The food here is soooooooo good! I have walked... 2017-06-25 03:32:25
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 300000  aVCjon0LtLgZFt-VhfNyXQ  vfQ1_fDr1noBW4ZUi2Nvwg
# 300001  2BBiMCxu_jw_l_Pt75CLIA  BzN-JRkAeKPU4PWn0gDRWg
# 300002  d20iDiHp_h_GlHZzQ3Jr8A  1hWXgcDzfvFmWMpBsXfqHw
# 300003  Kb9fvvfE8fzRYXxyg3z_EQ  vX2cntIyUUk7S9eINORF8A
# 300004  cgF7waB_t9ZpDfDmb-KhgQ  1qO3GVjDUoprTNaoNJFFaA
#
#                    business_id  stars  useful  funny  cool  \
# 300000  tgWxnsQ8XIFdGeOKWhz1uQ      1       3      0     0
# 300001  sLgnx_WFCjEoPsS6NwU70Q      5       1      0     1
# 300002  46fEorqn2nVbxdclHdHdKg      5       0      0     0
# 300003  AtIGlkUITdQFhAG_JWp-Og      5       1      0     2
# 300004  0YiRkVMR2cg17hk9u6nGhg      1       2      0     0
#
#                                                      text                date
# 300000  Never even got to go to the place. I was recom... 2014-06-24 23:41:20
# 300001  Sunday breakfast with my girls :) \n\nA "lite"... 2015-05-07 19:04:17
# 300002  Excellent food, service and atmosphere.  Great... 2013-01-01 20:34:48
# 300003  My husband grew up in Zenica, Bosnia.... I'm f... 2018-06-19 04:08:49
# 300004  Can't speak to quality of the pizza as I never... 2016-09-16 19:06:43
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 400000  7L88HD1AaWzBfarowlTbrQ  leAOJwVfzd_BN2H87t6wyg
# 400001  uHkUunNQGwB3abFGkjpLWQ  5qMaMl2w6Ot31iFV7_agDA
# 400002  WLtCJZpY8KPcupOyXpZhXA  6G3Ep4w5bGiUuxlIuN9Ilg
# 400003  LzPS_rqcXq6ZDztgL6eLxw  VEhmcGKZ7sCvc141ofOnwQ
# 400004  qf0-E2mDlzKTXFqAWu9RXA  UCDLpJgzc-zoJA31R7AvYg
#
#                    business_id  stars  useful  funny  cool  \
# 400000  xqfJZ57uQ8NAgLazfMVV6A      5       0      0     0
# 400001  EQ-TZ2eeD_E0BHuvoaeG5Q      4       0      0     0
# 400002  rQW9iupvhk6ScPn2VPNLVQ      5       0      0     0
# 400003  E9QzFNntGABauXJjii_Qyw      4       1      0     0
# 400004  tiVQ9_qoatNn--ITbMWRpA      5       0      0     0
#
#                                                      text                date
# 400000  I am gluten free and my husband is following t... 2019-01-31 22:57:47
# 400001  Definitely a unique experience. WARNING: don't... 2019-02-15 17:34:55
# 400002  The most unbelievable street food in the unive... 2018-06-26 15:46:05
# 400003  We decided to check Zepplin's out and switch o... 2019-01-21 18:12:42
# 400004  Love love love Rj's!  We have spent the last 1... 2019-01-11 02:11:36
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 500000  DWNPGpJySoDkuBdiXdtEgg  C8Oz6p3UrIYpOybp_VvhWg
# 500001  xn09zPAKvn4ODsXgyHdhnw  tFSyyQ9kj0YQB11QLRx-Ww
# 500002  zJ5lcTV-wDCBLDNCW6rN_g  6mraycxJKTd85By_YMRuAA
# 500003  9uwGOcXS-cCdId4srpitng  amsslRffqSutX3kuyrF-MA
# 500004  pFsuARExuybt2EEyx-7rSA  zDT4gH7mXP2PUVz6TrSM4A
#
#                    business_id  stars  useful  funny  cool  \
# 500000  ZmvZo795Rp3EnyHWHCGckQ      5       1      0     0
# 500001  IjtKwA7njLjTvZr0nFSLeA      4       5      0     6
# 500002  YNjyv0gfOr2g8lbmUpTnKg      5       0      0     0
# 500003  F1xE--Gb4rNFAwHkNkV31A      5       2      0     2
# 500004  X6GzniQjbm3YFWWwzDrBkg      5       0      0     0
#
#                                                      text                date
# 500000  This place doesn't get great reviews, but I'm ... 2020-06-07 19:07:53
# 500001  I have my favorite spots in Armature Works and... 2021-05-09 14:57:45
# 500002  I thoroughly enjoyed this place. My son chose ... 2021-07-07 17:44:48
# 500003  Another place I've been going to for years and... 2019-12-10 03:06:15
# 500004  The bright orange building is hard to miss. AW... 2020-06-09 03:48:41
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 600000  FzUIuyEv0-IGDD-HgNzMFw  ygkSutTb8BXT2FWet7HB4w
# 600001  X4pf__trHaFzzYCQnQNtSg  WDms6ne7odON8vtdL-b-xA
# 600002  OaGJJMW1Bk2XD2yfmMlffg  ahgaIIujY6R8HsEJfRnLUw
# 600003  d8a0jFNvN7k-4CSv4d2HZQ  LzPNpoqbx3Pw18yX_aEHwA
# 600004  FqJqBbDqrs-GK2HUW13tdQ  B7laWmiMZHgsxiHk2U9H9A
#
#                    business_id  stars  useful  funny  cool  \
# 600000  PVqNBGihp6yNv6HTQf7CjA      5       0      0     0
# 600001  STtVemevd30WoiZWn_taiQ      5       0      0     0
# 600002  MfyUK58sdUokMdIZNdem0w      1       0      1     0
# 600003  7IU6885SDuzEA9JfrP--uQ      5       0      0     0
# 600004  bqXjSL_8Pu_4xPL84EUjDw      5       9      3     9
#
#                                                      text                date
# 600000  I live nearby and was tired of the same old na... 2018-08-01 13:18:03
# 600001  This Pollo Tropical is great! Quick and friend... 2021-04-11 21:30:56
# 600002  Not happy with this place at all. Saw somethin... 2020-12-01 20:46:21
# 600003  This is hands down my new breakfast food spot,... 2021-04-06 15:43:59
# 600004  What a cool place. Have a beer and a haircut. ... 2020-08-06 19:57:03
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 700000  DIczy7s-pVHPDsLOGOL2Qw  U6FE3zdL9TJLOgW1_R8kPQ
# 700001  YYEUQx1DYbCKBHMRSM072Q  NfQOO5jBV8MUGu5IhwWHgw
# 700002  Sv4XiKzP4exnjPFfO57pfA  0DB3Irpf_ETVXu_Ou9vPow
# 700003  i_iyTSXZWRaErVif7QrV1w  Y_gIg4xxTkpmj7yoX7Ay2w
# 700004  sIAoW0lVLWkKr7T8JTJNaw  ePDSaeCKBXPLEfw7KiZrug
#
#                    business_id  stars  useful  funny  cool  \
# 700000  g5ogvPhw3PSobtaZFkdEXg      5       1      1     1
# 700001  ri1v4DsR33yeH9SK4Jz4gA      1       1      0     0
# 700002  uE40984_YDgVvPeRpFcCaQ      4       1      0     1
# 700003  UhjfJpaAzgSYrTZ_dMMF1Q      4       0      0     0
# 700004  lTlii3QHEVvsagPGsCtu9w      1       0      0     0
#
#                                                      text                date
# 700000  AMAZING!!!! My husband and I stumbled upon thi... 2014-11-18 22:42:48
# 700001  Called here on a Monday to order a tomato pie ... 2012-07-30 18:01:41
# 700002  Jesus this place is expensive lol. The BBQ dis... 2016-05-27 22:41:02
# 700003  Food was excellent and they give you huge port... 2011-07-15 19:08:03
# 700004  This place was alright when it first opened, b... 2014-12-13 14:46:31
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 800000  Cd7xUMhqceY9KDkgoJmGWA  JM2PVRrNAXTtHVT5Nbo3jg
# 800001  rD8FrKlxEGkskVnVYqoVWw  eTz0g1UwpVo8k9Oc7K-Fpw
# 800002  eWleaM0Z5YZaCmNLLw2Rkw  DnYce-7vYmdTXkOrpTF11Q
# 800003  JOvpm4fNFTzsAfHCs-IvPQ  C-1KNdwFIK_fle57uNPvXQ
# 800004  DYvcwcTbSCRcRTtP7iUFOQ  0ymDiXSbvjyqA0VOWl4-KA
#
#                    business_id  stars  useful  funny  cool  \
# 800000  AkpAXXVmnhHzgi9u51QoJQ      5       1      0     0
# 800001  ocCJqUvYDVrPE2RURgXArg      1       0      0     0
# 800002  X6tbwAVDNHv7V60nB5wXiQ      5       2      0     0
# 800003  SyKHFYhRzW1hlwDga5EWWw      5       0      0     0
# 800004  4ojRyf5RfZArkkE9U9bfNw      2       0      0     0
#
#                                                      text                date
# 800000  Ya know what, I like this place. I never think... 2007-06-10 00:45:22
# 800001  Went there Friday night had terrible service a... 2017-03-05 21:31:06
# 800002  Great find! \n\nA lot of reviews on here seem ... 2014-07-30 06:37:49
# 800003  So far ,this New Orleans whole foods market, i... 2011-08-31 21:46:07
# 800004  Airport hotels. This stay was booked at the ab... 2014-04-04 10:32:12
# Procesando 100000 filas.
#                      review_id                 user_id  \
# 900000  tOEg4hnl5U6Ze7qNQy9uYw  tyGuADf5u4hs_LuWKpgqbQ
# 900001  PrOXzSdz36xsFOZv8ADJ3Q  pVtwO671PJ0RmQQjDOewjA
# 900002  cgmBzPF8eUy2Rv61vbY9fQ  Z2gO-cuYF_gScOqSlqceJQ
# 900003  Hl-Gze9qn8i1Gv__BswphQ  Hg4MoabxpSMAGCV1IKqhVQ
# 900004  eA_aVYXdapLWFFnjAOuKZQ  Jv-TCKsCbaRijOxkIbCwNg
#
#                    business_id  stars  useful  funny  cool  \
# 900000  vF_QwGltBpVesMMGclzB9Q      4       0      0     0
# 900001  JWqbjm0wtbbciu_Gb6Eqyw      5       0      0     0
# 900002  6fh9vYY6eur94JGW97aaHQ      5       0      0     0
# 900003  3ucn3_cDf1WV0DsFgoTfyQ      3       0      0     0
# 900004  YuCI8fv9oRHU7aiiA5xrZQ      1       0      0     0
#
#                                                      text                date
# 900000  Although the classic staple margherita pie was... 2015-02-22 18:16:34
# 900001  McNamaras was a great Irish restaurant. It had... 2018-01-15 15:44:25
# 900002  This is our go to and the best local place for... 2016-04-03 17:17:39
# 900003  Overall our meal was just okay. The menu said ... 2013-06-03 19:07:09
# 900004  This BK has twice in a row gotten our drive th... 2017-06-20 20:19:04
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1000000  1yzkzMBuDc0oIATmm-YT6A  batsML880B8-BMV1YBh0VQ
# 1000001  p1He-R5tvsxamxNF0Bf-cg  T9n6TKhnkqwh7u3a70O-pQ
# 1000002  fOOZEC8D2f1hI6bs08X3gQ  4zUi7exGanxHz_zXJuHjMw
# 1000003  ZoeZ_aC_CiWSuqvfe38nAQ  bHNxtcIKeU5Ifnd4BwBoWw
# 1000004  ygAtxZ1Gaimqj8IZGPobRA  W9zN7u6b-e3bkZ69W92fig
#
#                     business_id  stars  useful  funny  cool  \
# 1000000  NLV0ppsHTiJk6JVdFSxVAQ      5       1      0     0
# 1000001  c_xAbBTeiIHqPm1zMOvQcg      5       0      0     0
# 1000002  Sv1MEZP-mMfp8SmE0hwYEA      5       0      0     0
# 1000003  KBG3GV4WHU-iLLSWiapbJw      4       0      0     0
# 1000004  BX3LLonrLLLfVX-tNrE7yA      5       1      0     0
#
#                                                       text                date
# 1000000  Pleasantly intrigued by the combination of bre... 2016-05-29 00:29:56
# 1000001  I am not sure what I was expecting, but this w... 2016-11-19 04:50:47
# 1000002  Mmm....still thinking about it right now. The ... 2015-01-18 06:41:40
# 1000003  Very good even by Nashville and non-Nashville ... 2011-05-10 02:24:14
# 1000004  New location is beautiful! This location is st... 2017-11-28 18:22:51
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1100000  TLbcdHt0O10deiUss--2Mg  z1MRcX51l2CSLMlhkZOsFg
# 1100001  wAADnLi_6ejMqVHGap9SWQ  q5bEuV2_PMI0yul7DHk5TA
# 1100002  lhJLTuNfX2-tcqjXY8u2nw  sHnXM2I9RxDpmJi5RG_UPw
# 1100003  sfmAALLPYYjzedVO1BIsiA  yyTzNpUEwIQFqSk59lOpDA
# 1100004  tQ6-_QeK3LFWUh_3d3rIbA  XCRHoUfI2ZE5N108qCxHzQ
#
#                     business_id  stars  useful  funny  cool  \
# 1100000  avKQ--Xf0s7C7yVSPC72Fg      5       2      0     2
# 1100001  QXJR1j949PHnH9ImB6xUcA      5       0      0     1
# 1100002  C_csOMzSkq3Ufau_rKmTmg      5       0      0     0
# 1100003  rNfFdGIFT27ItMzG3qQCWQ      5       0      0     0
# 1100004  SlvVcacPWf6qMLFH6lPQiA      3       0      0     0
#
#                                                       text                date
# 1100000  For a few years, I been going to the Victorian... 2019-12-24 01:23:08
# 1100001  A breath of fresh air!\nI was here on Black Fr... 2017-12-02 17:49:01
# 1100002  Food came out fast. Coffee was good, albeit a ... 2019-12-28 17:06:58
# 1100003  I wandered over here with a friend while we we... 2019-12-08 17:49:58
# 1100004  Saw there was another Colombian restaurant in ... 2020-03-14 17:23:30
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1200000  IcKLtYyDlFQ_aO2tPLJ-HQ  qhMyqD0vR4tUgg4whTX-Gw
# 1200001  xKi8KMWV_23kxWt_wN61PQ  w5pSmzQIobsQ5ur9PI5FBw
# 1200002  aOyj4grg-LWftCdzT2-Zrw  r9S0VYrdXJrdhfR7OXj8tA
# 1200003  N1CHik3YxplcdgYaSs88RA  YnLSNOxNv0I1AcbotjXxmA
# 1200004  aTtuQLacXD58jquFxwYJIQ  YrBIxPnf_qZImnrZgCLTbw
#
#                     business_id  stars  useful  funny  cool  \
# 1200000  tc6jKQiRjFO2M7BylwHVrg      2       0      0     0
# 1200001  Qrjvzbrbe99YzB9OfuJ6WQ      5       2      0     1
# 1200002  WsCIwMlDwt8g4i40JS_nGQ      3       2      0     1
# 1200003  YmUVCO5-ZdSenHVKEJE1rA      5       0      0     1
# 1200004  TuYACtcbbiArXzubj2BIRg      4       0      0     0
#
#                                                       text                date
# 1200000  I had a simple to go order. When I walked in t... 2019-10-09 04:10:46
# 1200001  How do you rate a franchise like this that is ... 2017-07-14 22:16:43
# 1200002  Updating my review for the fact that I came he... 2019-07-30 05:24:56
# 1200003  great atmosphere, friendly service, great food... 2019-07-24 18:21:11
# 1200004  cool spot, we had dinner there and brought our... 2019-08-20 04:34:22
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1300000  gIFz5b_Uk0cunQS0rPOEZQ  ZcogXYI50Ja_6b4CdEG_0Q
# 1300001  W-j2SAKiXTzlgbObBKROYw  HsBgFYyr87AwwRjWNWSDcA
# 1300002  P3PEwojAnnkO9Qo3JImyZw  IVg6uzoGp6ZYIPnX8Q7S_Q
# 1300003  35rfMCVDP0UJGDI_W9qymQ  ilCIXYYSAgAzMpReYeG0GA
# 1300004  pbHCo1eoFOsphFUGSepPfA  xAcAmIRGv4sTSWk_hAQ6hQ
#
#                     business_id  stars  useful  funny  cool  \
# 1300000  twuh803Q03U9X1YGnJgilg      5       2      0     3
# 1300001  9IXjieBjg-i4G6vfailfbg      5       0      0     0
# 1300002  kkMxWSIJ88BG8bVn71RGEA      4       4      2     3
# 1300003  -tWltjTtepDjVaKD4iGdDw      5       2      0     0
# 1300004  dtU_DsHVOCi-2-mWe7gabw      2       0      0     0
#
#                                                       text                date
# 1300000  Stella's is amazing. The food is delicious. Th... 2021-02-02 22:27:55
# 1300001  I've only been here once, but I was impressed.... 2019-12-06 18:45:15
# 1300002  Everyone has said it SMALLEST LOUNGE THUS FAR\... 2019-10-02 00:48:24
# 1300003  I've been to many Latin bakeries in the Tampa ... 2021-06-27 14:54:06
# 1300004  I made a reservation for a party of four at 7:... 2021-08-01 14:50:30
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1400000  Iwo5itq6c3TRgOlitqqQbg  j3XwzFVZF8p54XUWRExhFg
# 1400001  MioRUGRGTyGdQWOT_8VxXg  sUU2F1cjLF-Mg6vgQ0opVQ
# 1400002  QYL-v6i8h1CaAktk4K8A0A  GDiqMbL5SKcaqyvM8Mlevg
# 1400003  5bVGNFTzAfDCDg7GNP-IyA  yy31-Je2nqE46kKq1qcK4g
# 1400004  9aElDs60y7JTIF0q6u4qpQ  f4Sig-C4op7yJ5rP60yiFA
#
#                     business_id  stars  useful  funny  cool  \
# 1400000  9v19T4fTmMl5MPXmdUqWAA      5       2      1     1
# 1400001  lau2jbBCG3XohoAvCRIm1Q      5       0      0     1
# 1400002  yRHKBFRoddwF5iVevkS4ww      5       2      0     0
# 1400003  Qsf6aYZHrP5SLioZXQrpXg      4       2      1     1
# 1400004  wjUlOsBLLnxpprgI-sSiDA      1       0      0     0
#
#                                                       text                date
# 1400000  This place knocks the socks off your coffee ch... 2018-01-25 19:08:35
# 1400001  Delicious! Delicious! Delicious! Can choose th... 2019-06-07 02:26:15
# 1400002  My business associates and I were in the area ... 2018-11-28 01:51:38
# 1400003  So the food at this place Ko Modern Korean is ... 2019-02-16 17:32:26
# 1400004  I would not like to give no stars! Rude and sl... 2019-08-17 15:50:02
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1500000  2t2YmwzrNSj9YUiGpIv6Yg  r3MuVuqa0gisQgL0I5Lb0w
# 1500001  OPTs5QmfwkYj8aAGcl9MTg  8YVJrnJyxG4pd6xyh6Wpqw
# 1500002  JaO0vy4gbURIMXGmFV1gug  gDKTzkU_FrnkOP7oBOIs_g
# 1500003  RFMpNl5DaHJee5qrb87fLA  5f3_kcXc67IKgL4aG5LixA
# 1500004  sUvC4ZCp9nkU6ts-unwqrw  UaGKqcjVs-CORc6Tdw_62A
#
#                     business_id  stars  useful  funny  cool  \
# 1500000  L-wv-QK9VoUZX6zUcJwSSw      5       0      0     0
# 1500001  VQcCL9PiNL_wkGf-uF3fjg      5       1      0     0
# 1500002  t08G_MSwHGMBUlCp1I5BUQ      5       9      4     5
# 1500003  GJtRRcx44M9ptMUYxccUeg      5       1      0     0
# 1500004  wB1Tin0OW1JRpaKM-E3ZYA      2       2      1     0
#
#                                                       text                date
# 1500000  The best breakfast and lunch spot in town! Exc... 2018-06-22 20:42:15
# 1500001  The chargrilled oysters were AMAZING. Hot, but... 2013-10-10 01:18:10
# 1500002  Our last night in Santa Barbara called for som... 2012-08-18 22:18:41
# 1500003  This was hands-down one of the best gluten fre... 2017-02-11 19:56:47
# 1500004  After waiting almost an hour for our food we t... 2015-11-07 18:11:54
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1600000  3BfJtnisMkBxHSmxr5cqrA  i6L9I8xDF-di3kgvDewnjg
# 1600001  TXxNGl7uxYU5wbHFPuzjHw  H1YXclHTyYh42VWSh9wlCQ
# 1600002  2hoDhyrGs5vvrt5VxksIMw  Xw7ZjaGfr0WNVt6s_5KZfA
# 1600003  hY7bKQsnGOOLiGRPNybkGQ  u69-z8YjQJVVna3HEVkPXw
# 1600004  hv7-u0xh_mJWeTsiYVfSPA  AxJKr7JukqZDtg_LDo9UBw
#
#                     business_id  stars  useful  funny  cool  \
# 1600000  Q1wTWAhOaoOZQRiGeL6N7g      4       2      0     0
# 1600001  -mVpEeb0zGMv81_IWoXT5g      1       0      0     0
# 1600002  0a9zhrYfp-KDqhMxA3bWWQ      5      10      3     4
# 1600003  RQAF6a0akMiot5lZZnMNNw      5       0      0     0
# 1600004  4JWuSA8tyXHteRgh_hU_Cw      5       0      0     0
#
#                                                       text                date
# 1600000  In a town where great Chinese food simply does... 2013-11-05 02:42:30
# 1600001  TERRIBLE customer service. I live in Fishtown ... 2015-07-24 21:52:00
# 1600002  Hmmm... why is Hubig's marked as closed? Down ... 2013-01-12 20:26:42
# 1600003  I love their cheese steaks !!  It was made per... 2015-08-12 05:07:43
# 1600004  I loved this quaint hotel! Location was perfec... 2016-06-30 00:50:51
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1700000  E99K6z5aOdP6t2W-XJL_Gw  uVFXps-VBIS_3R7prf1eOw
# 1700001  EL5MVJsDmzU7ESj3mh4g2g  4Q6NJ2xJPE7EvTz0CIcnGg
# 1700002  GWRCi6ggcUBVcB-DtZ33_Q  T4EsSKT3FZS9uqU-NUgoQA
# 1700003  uteGNIBQ2041cfRlYWHR_w  Fr-5f2-NCX8MH6m-KClcng
# 1700004  fcRxhaqSmwa6BX40Ia0opg  KjgMNVvWUKcEzQsUUQPjgQ
#
#                     business_id  stars  useful  funny  cool  \
# 1700000  kNe-WMFqoUbxhXpOs3-U4g      4       1      0     0
# 1700001  L9CFXQbU79r6PK8Cy9aAgA      3       1      1     1
# 1700002  guhR6xTEK5u3-LDi1ELCng      5       0      0     0
# 1700003  HUZV9OAtqj0sGBo4g3ZxBQ      3       3      1     1
# 1700004  VQcCL9PiNL_wkGf-uF3fjg      2       0      0     1
#
#                                                       text                date
# 1700000  The atmosphere is real chill. The ambiance is ... 2014-03-13 05:24:48
# 1700001  I ordered the #1 bento box which included kimc... 2017-06-06 17:48:17
# 1700002  I have had two great experiences here! Both ti... 2014-07-12 02:40:41
# 1700003  Oh Uno's..\nUno's has been pretty wishy-washy ... 2017-01-01 19:14:50
# 1700004  Beautiful day in NOLA - upper 70's and sunny w... 2011-04-20 20:37:35
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1800000  hyNO_RFwWkFzMO-9-Uyl0Q  vFzlaPSa0WK0c4Vl604vRw
# 1800001  d992pa48YBcjKlk7frXjDg  D92hW06xTzKaQpxAiIXWjg
# 1800002  Kt2LLEvtagq-l3Bn59sUfw  NTlvJ8oVBrjKMqgIBKC3nA
# 1800003  m7Yb5naBzprUyVCHY3Pcyw  pbNXvJlnNRWGo-65VJ4EIQ
# 1800004  LW8fBPFYwbluCGRzMdNERw  -FH9K-xkwdE25gH8lGGQ3w
#
#                     business_id  stars  useful  funny  cool  \
# 1800000  mLGMIC__z6aK5JWUT9F6Ag      1       1      0     0
# 1800001  vetEEi-77Mlik9SogwlcFg      1       0      0     0
# 1800002  jqe71gh5khnwbKE-70veWA      5       0      1     0
# 1800003  rx4fcNjuqoaEugMPq5PBfw      5       0      0     0
# 1800004  QHccEcja9h1Wk0b1wWBnxg      5       4      0     0
#
#                                                       text                date
# 1800000  If I could give this zero stars, I would. Book... 2019-01-24 03:40:55
# 1800001  We have been going here for about the past fou... 2019-06-04 23:14:03
# 1800002  I've been here two times already and the servi... 2016-06-10 15:03:53
# 1800003  This place is fantastic! Stopped in for early ... 2019-07-18 21:31:15
# 1800004  Great animal hospital.  Dr. Sanguinette (sp?) ... 2010-12-28 16:19:04
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 1900000  yHLb77wpVxAloM3eTheSrQ  nUEJd-E1F6hP7KDVLkcV0A
# 1900001  ueBj_HRiA0t-DvHhx7fIDQ  tWEq9oSJNGAPNlZEcTngdA
# 1900002  Fo3aM0y2gwm6Jv3mPFPQdg  vZi3JqBWdtXXNCcO2smgQg
# 1900003  FnbJGWti0CJnFzjXb4Te9w  bNy8DSvJkWDvkwHvOxQ4ig
# 1900004  UJ_NOfwE3rK2u7SCG-XWrw  4euAHick6UGLHf3mGaBLTw
#
#                     business_id  stars  useful  funny  cool  \
# 1900000  rIv_HEmn9ugEAbBS_sSLKQ      5       0      0     0
# 1900001  h0wHeh0hTt6Us4W-1SHQOw      5       0      1     1
# 1900002  DveLJu6Wo8UCunM7iarKhA      5       0      0     0
# 1900003  h_Pu984hndy2gPc4yvQLng      3       0      0     0
# 1900004  0kEyHYpI6ixtq87LV6I1Aw      5       0      0     0
#
#                                                       text                date
# 1900000  Why go all the way to the French Quarter for s... 2019-08-23 20:15:38
# 1900001  Now that the construction of the Southwest end... 2010-11-29 00:14:14
# 1900002  Everything I've had there is delicious. Two of... 2019-07-20 18:07:02
# 1900003  This review is based off of three visits.  Wal... 2019-09-15 18:17:46
# 1900004  I really like this place, the prices were reas... 2019-09-29 00:56:57
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2000000  NxIV6YoOfsiBSxrNF5i1Dw  r5YAim_lxd4Js2gQVGeLsw
# 2000001  S4ULMYax-92NERQvAivrfw  QJIbIcjPb6qhRnb1d4sTjg
# 2000002  uClUShLNMwHJNLgS9J5poQ  IiVjDaSDELbxLIWu0_Ucrw
# 2000003  3DrBtGCx4N3aXrbpDAxExg  K2vRxDY1uuxtm_YEEfQ9wQ
# 2000004  uNXSrvw9jO4jarViJcfmvg  ctgPXpW4NitQisBWHaS1YA
#
#                     business_id  stars  useful  funny  cool  \
# 2000000  T3Bbtht3jO2izyO6f6W8bg      5       3      0     4
# 2000001  EY5cTfLf9BNG3tgoez9fKg      5       0      0     0
# 2000002  6nCLoE5WfY69AywtTmg2Lg      5       2      0     0
# 2000003  wMQMMxaGq0HPG0mApezXMw      5       1      0     0
# 2000004  5uhG34VRsD0A6lOY8F41Dg      5       0      0     1
#
#                                                       text                date
# 2000000  Pros: Makaylah: our bartender and server, she ... 2020-10-31 00:18:49
# 2000001  Authentic and Perfect! \nAs someone who's as b... 2021-02-09 03:12:34
# 2000002  Great fresh food for lunch, I had the appetize... 2020-10-30 00:04:00
# 2000003  I heard good things about Ahi when I moved to ... 2020-05-03 01:21:43
# 2000004  The Habit is yummy. Had a charburger with chee... 2021-02-09 05:32:37
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2100000  XvD_tfXeYTJ7eRyRtjKyKw  9BdFdeKaoPMzEPBARQmaUA
# 2100001  nMsWLQT4wRrIPFY0xtPCJw  9GpMrHTbb_1lQuVB5UF4qA
# 2100002  A6KtvedL1HrX_ZeNJB_43Q  UI_yvCY5-HffZC1z3V3cPA
# 2100003  eO0UW7lqjxJhABxwTXQIeA  jJ44mlWjeUEAsfs1a00jdQ
# 2100004  8V22c0_rvDLIys3PbnHxYQ  _kl4BixSBcvmEexAR1ydjg
#
#                     business_id  stars  useful  funny  cool  \
# 2100000  MAikFvAmH-UwqGAu-2PStw      5       0      0     0
# 2100001  mPKqBWLSD8wxJLJ_4juY2w      5       0      0     0
# 2100002  v7NTRTUyI77Dd5wxO_JAPA      5       0      0     0
# 2100003  _b4_ErF9lEE6vePd3lAJgQ      4       4      2     3
# 2100004  UfETwTB6vJa6HmnbVrPZaQ      5       0      0     0
#
#                                                       text                date
# 2100000  The staff was extremely nice and very helpful.... 2014-06-20 18:08:09
# 2100001  Such a cute little chocolate shop! Great stop ... 2021-12-10 00:04:27
# 2100002  I absolutely love this place. Everything from ... 2021-12-11 18:33:35
# 2100003  I'm so glad we now have a restaurant like this... 2011-07-14 17:52:54
# 2100004  Everyone at Woodcraft of Boise makes the buyin... 2021-12-14 01:09:55
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2200000  tddkSqk5iIlF0kIIV-I7ew  r7-NuBhrgFd8zm0ci13HcQ
# 2200001  5Lyt_PDPlHdLkejk9uq4Jw  1W2ZqgEIjVffDS-QXkd4oA
# 2200002  YKxrVp07Q53x-P2buThANA  -g8mbRk54fHks-38JkwwkA
# 2200003  XITVk2Ggfus_YFT8it82WQ  SdurPEg9GYWvBp-NcEF4ew
# 2200004  Id1E7Jd55cpWC0S94WBgzw  mjCZ94x9qHzeexz0_J4ruA
#
#                     business_id  stars  useful  funny  cool  \
# 2200000  oIA-gfxJAM0gjb0C39d24Q      3       2      0     1
# 2200001  cp2ZSHXibAxCHvJoPPyLag      3       1      0     0
# 2200002  6lwgfwZkEnRHYcp6jKWlIA      4       0      0     0
# 2200003  iDrmpQwGAAmftLzWqxEomg      5       0      0     0
# 2200004  rjFGFcTduZ5wh-5pl1IbCg      5       0      0     0
#
#                                                       text                date
# 2200000  Not my first In N Out,  but its nice to get on... 2016-12-21 16:06:50
# 2200001  I was in NOLA for a few days and craving salmo... 2013-04-14 15:49:45
# 2200002  Food was great and came out in good time. Our ... 2018-10-03 21:44:03
# 2200003  What a great lunch today, my waitress Ms.Jonni... 2017-05-11 21:34:54
# 2200004  Tours by Isabelle is a professional outfit. I ... 2017-01-05 01:43:38
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2300000  UG_gMhhqakViXMZs-qDO_w  Uq7ZLvOq5BS33b7PIafvSg
# 2300001  cGfURNgXOpGvGNDd_ntiWA  EAHCCgMFoJxlOPcCPQ91SQ
# 2300002  7cd9IdRHjwFTyHEJVFbwdw  x74KzrAkjGusgLFAgrJn9Q
# 2300003  g81fEqzM5MuIoOI7lrF5Ow  TJHhJVgb2tWnhswALh1v-w
# 2300004  Xmnl7VLwzZFHL6VYlF6rIw  8RkMPXodOhoBTVSuuA9EwQ
#
#                     business_id  stars  useful  funny  cool  \
# 2300000  EagkHaaC-kUozD3MPzbRIw      1       0      0     0
# 2300001  g5J3EkiaC1AggoxVeXC6xA      4       1      1     1
# 2300002  h5Y6iLn5VogLWcfT5tnANg      5       0      0     0
# 2300003  cFiQCavspCuUI1xBXuAQ0A      5      16      3    11
# 2300004  IkY2ticzHEn4QFn8hQLSWg      2       0      0     0
#
#                                                       text                date
# 2300000  Party of 3 quoted 30 minute wait. Waited an ho... 2016-04-17 17:55:50
# 2300001  We stopped here yesterday after the book fair,... 2016-03-13 23:27:00
# 2300002  Wow. So so good!  Well worth the stop!!  The f... 2018-03-28 17:13:31
# 2300003  So good!  My partner and I love that this plac... 2017-04-23 22:54:42
# 2300004  We knew we had to stop here while in Philly, b... 2016-07-10 15:26:40
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2400000  hvSaxK-vu8L6cAN58L8bzw  aqDcLzgXlFzlU-Sc1bTHUw
# 2400001  VyU0Ohn1Gn0Rdf0ImngVug  bxTEp0AbmdXEAxmEIhfm_g
# 2400002  auRdwMwjgRi7JsDDKV0orA  7BDIqQI2ffaAN9OZbZCUhw
# 2400003  Dc_cty5WawS_FWKW3Eiddg  fDtLSbdd8A3UaXiDMGcUuw
# 2400004  ZFqm4DhhSm5f7ODE3Z04Lw  Z5E-JeUUZD9S_Ft8SZSlmQ
#
#                     business_id  stars  useful  funny  cool  \
# 2400000  9X2rQUHO_ka0k7tu7wr_7g      1       0      0     0
# 2400001  f2YXWEafk6m0fiHZjp8Y8w      5       0      0     0
# 2400002  XqSLir6xs3I6ntf-xIQzrQ      2       1      0     0
# 2400003  56p17O_bHVEPBh4m41JAsA      5       0      0     0
# 2400004  JyOfFuVEGnhLdoN3K1WewQ      5       1      1     0
#
#                                                       text                date
# 2400000  We were greeted nicely and seated right away. ... 2013-02-14 13:08:29
# 2400001  Had a wonderful ribeye and great service.  The... 2016-08-19 16:39:48
# 2400002  We went to City House with high expectations f... 2012-06-18 20:42:21
# 2400003  Just bought an incredible piece of clothing- a... 2017-08-13 23:02:10
# 2400004  I'm here several times a week if not more.  Fo... 2018-04-12 19:17:48
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2500000  5ReNg2IeR0gtj45GNAr6Tg  vrw9SwlOrrgo2nHtwp-SmA
# 2500001  PvQrwR1hKLA7I4dxJx0emA  W7YIgEwo1t5RGj1Qi2Y1hw
# 2500002  78O6qdrgMxtLSreh6KKdHg  imhUgZdEXe-JLZT381S6-w
# 2500003  iLTFAc-87-sst9Awfk2iXw  umOX1uhKPAdqTNCwcuwm6A
# 2500004  upeg0sU4ogvEixC_eSodcQ  wVP8TPNvBrBpnJTnUHH5yg
#
#                     business_id  stars  useful  funny  cool  \
# 2500000  ClPyuoDPOpIPutkhN62E7Q      5       0      0     0
# 2500001  CfxaspC1y3xfmL_AnA-7MQ      3       0      0     0
# 2500002  c6fWBSm-EHVwyFszTC5Mhw      4       2      1     1
# 2500003  3_z_ILjp4AUOiyyMsobKoA      4       0      1     0
# 2500004  1_vUF5wVb2Emo2GA1KxhZQ      5       3      0     0
#
#                                                       text                date
# 2500000  Saw spot from road and decided to give it a sh... 2019-09-18 23:16:03
# 2500001  I like to come here a lot, but today service i... 2019-11-22 04:28:15
# 2500002  First time dining here.. My friends raved abou... 2020-01-27 13:50:06
# 2500003  Stopped at Jalapeños today and it was pretty g... 2019-06-22 22:09:41
# 2500004  I had my rehearsal dinner here.  The place was... 2015-08-20 17:48:04
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2600000  nmSIdPwStR7oRKsCsjMBFg  5q2YwoXdEDoxVid1sxpJWQ
# 2600001  jn3IZ9jjWWkc7zl-rzgEzA  l2KC1Bl77xKv_BjwF1KK9A
# 2600002  LVul5THGY2YrOPAtydIpiQ  ujnyml6BDLTQlo0SVxiyNQ
# 2600003  HxHlO7U15W09b-4vUphlFA  AIuff_yLpuaJTWAbQiJXRw
# 2600004  0MigU6kqtudnsfe121cUeQ  b6X8xav0PJ8vWQrCnx_iJw
#
#                     business_id  stars  useful  funny  cool  \
# 2600000  IkY2ticzHEn4QFn8hQLSWg      1       0      0     0
# 2600001  PQ0QbT5I6V8JvOm0NRFlFw      5       1      0     1
# 2600002  uZsStnH9w2xY15og9VsQZA      4       0      0     0
# 2600003  41b1cZSlkIBA_87-jCcXlw      5       3      0     1
# 2600004  8Npqlzl494AIMX_4pP4MJw      5       0      0     0
#
#                                                       text                date
# 2600000  NASTY FOOD NASTY PEOPLE. I am from LA, and wen... 2019-07-19 14:56:46
# 2600001  Every sandwich is a work of art.  Just simply ... 2018-02-17 19:28:33
# 2600002  Carmine's is a tradition in Ybor City. It is o... 2019-06-08 18:39:38
# 2600003  This place is tiny.  It looks like a renovated... 2018-04-10 22:13:49
# 2600004  Awesome wines with an amazing owner who truly ... 2019-04-21 23:23:57
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2700000  2DHTb2PWSoOPuSpP9Dw97g  Xp5Hj2SGl0eDp3Ine9a_vg
# 2700001  HvD7iyvPVMlIAAA5MG0yKw  zuB1hpxFSo6-4c60JnNrDw
# 2700002  e8xDNZ9smQq7sOfTxkMdPQ  leGThcGn92HDaP3JYXTmPw
# 2700003  hvb92NabwjDo97lfhBhP8Q  sHuuzmjHtyPSeE5wpJAfMg
# 2700004  Cxb6hSkkgwGZa4xOETsmkQ  WGlgFLu4CHrJZoCDgvpHlQ
#
#                     business_id  stars  useful  funny  cool  \
# 2700000  X_Zoa9pSIyel343hXkp_KA      2       2      0     0
# 2700001  pRk4_ElCW8pZU58WIZ8jMg      5       0      0     0
# 2700002  6KoyHbN2qSUsioqrjXLeEg      5       0      0     0
# 2700003  JYVqfn8xRNIb-VFvsm-W2Q      1       0      0     0
# 2700004  OCT4aNBYo7Dx0qHol-ziDw      1       0      1     0
#
#                                                       text                date
# 2700000  I hope the owner takes note that all these bad... 2019-06-05 01:29:34
# 2700001  Garrett and Sam were very responsive to my ema... 2017-10-23 16:51:24
# 2700002  Amazing small plates and cocktails. One of my ... 2021-02-02 21:22:19
# 2700003  Overpriced, cheap, bland Mexican food. You get... 2021-04-12 02:48:01
# 2700004  Awful service! Oil changes are cheap but any o... 2013-01-08 01:16:47
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2800000  JR87D8B8naIq5ATpmW0duA  VcM0-cn-ZoqNFrjKtoiZkA
# 2800001  Zm25KeR-VVZjEujJ8ZE8Tg  DYqM7nQUN6111fZ_eq32QA
# 2800002  TBVz7drTMpCkFnin_T6fGg  LrBdK9HdRUHubu9CJVkSxg
# 2800003  ExWWim-y7e9GtXqadtRohQ  lVylCKU-NyR83eMeI5cYFQ
# 2800004  0UcFniH9VXlwxqv3VheDvw  el_zVl2joLvYN_92fawEnA
#
#                     business_id  stars  useful  funny  cool  \
# 2800000  p1_n3VQ4O85n1LRvPA_Z3Q      5       0      0     0
# 2800001  mv4h0tqYMTR89L5GFk7O9A      2       0      1     0
# 2800002  Z-RG-NA1iwcUkFuxShGooA      5       9      2     7
# 2800003  efxiiiwXpF2pEsCfgeQc8g      3       0      0     0
# 2800004  fcT7GsBZCm8HSibz6hRKhQ      5       5      0     2
#
#                                                       text                date
# 2800000  The crew that works here is always on top of t... 2021-06-12 18:48:56
# 2800001  Food was decent, but they are sooooo slow. I r... 2021-03-29 22:32:26
# 2800002  Great place!   I always get facials here & the... 2018-05-08 16:22:01
# 2800003  3.5\nAtmosphere is awesome. Staff is friendly ... 2021-06-14 16:51:00
# 2800004  Love Brianna and the main reason I keep coming... 2020-10-29 03:37:16
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 2900000  yVrgDLL5Veg_mUnMptVGqA  Vwqqep8K-ivMSbf1l9ImyQ
# 2900001  5ei6tILr7hPGGzoiSxjrlg  c94YjpUvZX-ksIl72bkVXg
# 2900002  GjLpb6pAEr0OOzgopk2zNQ  ktcE-wMdSOWx5fK9f5JQbQ
# 2900003  3UZevboW4R4XEwPG1fKrEg  1TorheZj-EjqKG1CLqloDA
# 2900004  GwSr75nJ8JCIf6C6B6IxJA  vV9aBpKJ8hJorrl1ICD7RQ
#
#                     business_id  stars  useful  funny  cool  \
# 2900000  USVks6B2Xkf0WLmLIiXqMA      4       0      0     0
# 2900001  8LbqoxdnVjL-9Tc2JOG1jg      4       1      0     0
# 2900002  ZNKIaNEimccAeAWjqf446g      3       2      1     1
# 2900003  G9rBwcWp56C8r6ZFwVuimA      2       2      2     1
# 2900004  IMLngTfC_a7wLEIr3QklPQ      2       0      0     0
#
#                                                       text                date
# 2900000  Ate here during three year anniversary weekend... 2014-05-29 04:12:16
# 2900001  The theatre is ok, not my favorite but ok.  I ... 2016-08-06 23:26:11
# 2900002  I used this company because it was preferred s... 2015-09-03 00:56:58
# 2900003  Let me start off by saying that I wanted to fa... 2014-09-29 08:22:02
# 2900004  Ordered from Luca recently about 4 times withi... 2016-03-10 23:46:33
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3000000  HcA750mPTtKUYuWfHR7vAA  3vofzamIMkrS0PPf5aSmRQ
# 3000001  4C_k3xCaSdFXcotVICxYLg  tCRK0DNqtudWuLEq3IInhA
# 3000002  LInUEmtPAqlcqlk8DfrD9Q  60RKNAZwY5EUooJf624aKw
# 3000003  Dkl-JP_lPuDdE1ka8KMBFA  3jG-b8U7bnE1FPiCl_CE-Q
# 3000004  JgZFJVhMiOxcSWK2QAub6g  qwy5ZpzXgWCB2TMDmCpKLQ
#
#                     business_id  stars  useful  funny  cool  \
# 3000000  7_1GqlDlbkShY0az7J0XNg      4       0      0     0
# 3000001  Sd8NrlgB6SY6GEtIjPupfA      4       0      0     0
# 3000002  ikONTzFKwachQtFtoMGeIQ      4       3      0     5
# 3000003  XXFW9msW3P-p6t6vV0cpeg      1       1      1     1
# 3000004  B2Rk_FNhgFF-XOwesQw7FA      1       0      0     0
#
#                                                       text                date
# 3000000  So this place has the best OUTDOOR SEATING in ... 2011-08-15 08:16:03
# 3000001  Great food and prices. I recommend the gyro. P... 2014-10-18 22:46:47
# 3000002  Excellent pizza, salad and service! I came for... 2018-01-18 04:07:13
# 3000003  This place is just terrible!!!  We read the re... 2014-02-16 03:56:18
# 3000004  I took my family of four to dinner and the foo... 2014-08-31 15:52:03
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3100000  CDOYQS6qzlKRdwYQNv4D9g  l-niImD5wpjDbew32reWLw
# 3100001  GC9lc_0dgU0uIUwrrWXtBg  gwYE77ZX2fpFdOLeiR_64Q
# 3100002  XpJ-7LvcCGJAMfLntx4Ppg  mswloq-IjRr9yXLhBqBPAw
# 3100003  NibfM5jLVBGR9BpI_EsODA  groUJYuQRRNFIgWDargy6A
# 3100004  yhhsLhplieQVoMrdZn6U6w  tRDYb8Vd6VM5BpbVI89Yhw
#
#                     business_id  stars  useful  funny  cool  \
# 3100000  yr6U0Wk8LXR_OLF1ezHOhw      4       0      0     0
# 3100001  Kd2ldlgqcWP7drZ-ChG4Kw      5       0      0     0
# 3100002  NFzfuIFghE-HnrodHpaT6A      4       0      0     0
# 3100003  k79ygmdDxEDXtLlR_rPrmQ      4       0      0     0
# 3100004  iMw_LReFjEsvhFGrU1EKqQ      1       0      0     0
#
#                                                       text                date
# 3100000  Great prices. Effective bulbs in beds. Not fan... 2015-08-18 22:40:00
# 3100001  I've always loved coming here, I just wish it ... 2014-05-19 06:43:18
# 3100002  Nice place for take-out and casual dining. Gre... 2010-06-26 01:42:22
# 3100003  Food is fantastic. Zoe is one of the worst wai... 2017-07-18 16:48:19
# 3100004  My last review was 4 years ago when the owners... 2018-04-25 17:47:23
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3200000  4NSoPFlcetr8gKMYb9JDJw  rx0tAGJ2GIYGFa8K3t_tkA
# 3200001  yqTSAY3bsuoU9M6wnCg8ZA  l8IiNVerTZ4wzUNA5Me32A
# 3200002  jYy4YO1ymo_oUr22Cr9LFA  e4CL4rUo8qwiIfWWRKsrNg
# 3200003  1TeWRZ5LJkkG47VHBL-kwA  iyO_Z0aRGIxf2Wqxs76YLw
# 3200004  4bL52UXx3kQJu_mtyCQXNA  4wlR3Fgp6g4LTqIy9EVPbg
#
#                     business_id  stars  useful  funny  cool  \
# 3200000  ySKtGxlOYko_DQ7DQlPxBA      5       7      3     8
# 3200001  e6FOCNyrm1Bb03UKA0BDSg      1       0      0     0
# 3200002  5bvUvt7qj-f23h2BCCDHUg      3       3      1     6
# 3200003  sizJfLgymNruZFQUSVJ_BQ      5       1      0     1
# 3200004  9n-1LQLX3ntBfBtMwgSpig      2       0      0     0
#
#                                                       text                date
# 3200000  Recently ordered some Cigar City and Bells bre... 2012-11-05 16:38:54
# 3200001  I went there last night I was having fun until... 2018-08-17 11:35:39
# 3200002  New on the lunch scene and only open for dinne... 2016-05-01 02:11:52
# 3200003  Completely painless and hassle free. They came... 2019-03-19 03:01:45
# 3200004  I came here before and the pizza wasn't really... 2019-01-19 01:40:12
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3300000  4GCWRktbpMtjPSNQowEVmQ  0yyXKmdI9lHxFKzomy6yfw
# 3300001  QlJCOW0-HSGPJqZ6B053rA  GX4lio7E96sCpRsyUfzGdQ
# 3300002  JiDNu7jOw6bEh1y8Rg_hQA  zmgugyeeSwM0wtFcnRxdlw
# 3300003  dQmBOTM3rRfuH5Qc_8a0Tw  vlx1Vn0txmphKLtpK3L52w
# 3300004  FltbvGRdsTY4pZaKTI8qvg  FkqGDFPrQ707JUWN43HYXQ
#
#                     business_id  stars  useful  funny  cool  \
# 3300000  P5Lh73hocKqEpKhuSVlGuA      5       1      0     0
# 3300001  IGxrAQcqw8Mr1x9WLXQsNA      4       1      0     0
# 3300002  JpwG8sDNsHuD0f6NF6YuGw      4       1      0     1
# 3300003  IgFxKVu_yHlCJsQkTYPPeQ      5       5      1     3
# 3300004  -Gg-_RZTUItml37klrTXoA      1       5      0     1
#
#                                                       text                date
# 3300000  We had a blast with Nashville Paddle! My group... 2018-11-06 12:30:48
# 3300001  I came here with a large party (about 10 peopl... 2019-09-17 00:06:42
# 3300002  Stumbled across Rusty's while visiting SB...  ... 2019-10-11 23:25:59
# 3300003  Take out your phones and prepare for the best ... 2021-01-05 18:16:54
# 3300004  We were very disappointed with this experience... 2014-08-27 16:33:13
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3400000  8S4tqXXB7KoSWLPuU6H9UA  fxHHP4nQDIfv1heJSgQtvQ
# 3400001  B7B7WmlS8qBVmylGU9FJng  kkPgJv6KBFN15caG7NYYlg
# 3400002  l6gs8FVsbHERT-zI1mLmOQ  IsfzrB80aWj9jYVaG3WrzA
# 3400003  _6-suMMDZ_8m3qpjvrdtBA  crGnkZCp9Rr-Frclf6kjPg
# 3400004  xgULgSlXSDNmA7IxvS3qcQ  pj7MtKv6rLlMvOriCTaJDQ
#
#                     business_id  stars  useful  funny  cool  \
# 3400000  eikRexw04kC6siBDkFnayQ      5       0      0     0
# 3400001  l7VClHY6vvoTBSCP1-ZUmw      5       1      0     0
# 3400002  mK4gpsdN7qqb2MMUYbQb7A      4       2      0     0
# 3400003  pGM44vXYa6lke-dU4h-xpA      5       0      0     0
# 3400004  pfl45YV5Us5NvDm5cLremw      5       5      0     0
#
#                                                       text                date
# 3400000  In my 43 years on planet earth, I've never had... 2020-11-23 18:20:19
# 3400001  We were very happy with this business when we ... 2020-12-04 20:14:18
# 3400002  We pulled into the dock from our morning fishi... 2018-02-20 02:17:07
# 3400003  Super awesome staff from the moment you walk i... 2020-09-12 00:07:20
# 3400004  We stayed just one night, our first little tri... 2020-09-01 05:15:23
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3500000  cG3qE44b3SeGKBpOdE6wow  e60LLNK38baolPPlf06jsQ
# 3500001  w6eNSLt-4_RoQe3crYkzDg  LpWm-2cXzzW5xWuMOZ8RIw
# 3500002  zoYCScCawwkPFu-m0_fETg  vAFKiEFPtvNoBaX4hl8Bqg
# 3500003  31LWWvQv9gmnCh8KB8CsXg  0nY6sf3cWw6-eU-lOhUp3Q
# 3500004  fENu7okH1DfhhyIBOlrx9Q  wCF7KXtL8FEhY-aNbcrnbQ
#
#                     business_id  stars  useful  funny  cool  \
# 3500000  ZQ-Sg1tJXCKD6Dw9DF4X9g      3       2      0     0
# 3500001  0WkPwMoI1HxSP8jicwQOOQ      4       0      0     0
# 3500002  8NBb4aIeQvDh3OWRiIXYIA      3       6      0     0
# 3500003  lTeoNvVo9cNvI5DLRkl9Sg      4       1      0     0
# 3500004  aAXo_vX8YG10kytAM9SC9Q      5       0      0     0
#
#                                                       text                date
# 3500000  Long wait for a table and our pizza. I vote fo... 2015-02-02 17:54:17
# 3500001  Corned beef and pastrami specials excellent. B... 2016-04-12 03:02:52
# 3500002  In the location previously Jackson Tavern, Tri... 2016-03-31 02:22:12
# 3500003  I really loved the flavor and preparation of m... 2017-02-20 03:24:33
# 3500004  Ok... the ice creams just straight kicks ass. ... 2017-12-17 01:14:34
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3600000  D_UQUzXO6iwM7KLac7k_WQ  d0dXGxcRWj4Jh-MU_Qv82g
# 3600001  t3b4rx4DN_2g8CdoCFLSKQ  29e_Yjehr_evf2MDh23vnw
# 3600002  59iUmDGPn6ARcPJnjT_x7Q  bMNO5wpHFIp3s4ym5wa5rA
# 3600003  9gQaXdtbE4jbbDKsBiPHuw  IcowqfUjDSmdwtT0vp4pRg
# 3600004  guPFFyfX4AFbVzWZwcDRNw  FjmgJIvYxt5TTJSToiPn8g
#
#                     business_id  stars  useful  funny  cool  \
# 3600000  nAqeT12b0GrUTxKbCDVL_Q      3       1      0     0
# 3600001  UR9dzGGVfcJhHt_mG3bTRA      4       0      0     0
# 3600002  ZfAILO2iad90fCDtratcKg      5       0      1     0
# 3600003  ATO_GTUMSEYBZn0v1cqg0g      3       1      0     0
# 3600004  Z3QeFKDus2t8-pNu3Lu6gA      4       3      0     0
#
#                                                       text                date
# 3600000  I never ate japanese ramen before so I was qui... 2013-07-22 17:38:44
# 3600001  Nice ambiance, attentive staff, and good food.... 2017-01-07 01:23:01
# 3600002  service was phenomenal and my sushi order was ... 2017-08-22 00:18:28
# 3600003  Average seafood joint! They're a little overpr... 2015-04-07 03:08:51
# 3600004  There used to be a lot of these local German f... 2014-07-16 00:19:12
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3700000  H-xJ19gTqlMkztg6HRf3bA  ZwVz20be-hOZnyAbevyMyQ
# 3700001  F-hKIjioowQIEuFDedEbqA  5QRQJNdt3p6E7FWR9FEX3A
# 3700002  U2Qwvg9LM1HXiiHaxUqEFg  K_w_gaf01LrmGZgi3V3Z6g
# 3700003  3TD4brvBCcDFsTGtR6gQMw  4XEO4b2mO7U35LzxiSIkqw
# 3700004  Mfs9U7l-qdlVe4LUrT7ZvA  1I0FAXCtt-JBr03YAhfXdw
#
#                     business_id  stars  useful  funny  cool  \
# 3700000  I9JC-IV5AZzL7x0BzJqOug      4       1      1     1
# 3700001  NhKmg9F9uj4DCQpF9ehfBA      3       0      0     0
# 3700002  kegzuRTWVcIAfsmGmkfHeA      5       0      0     0
# 3700003  JJ1PdKT3BrLNmAJGAzLTWw      3       1      0     0
# 3700004  neOgjzBJYrRBO_WnQkMLRg      5       0      0     0
#
#                                                       text                date
# 3700000  Rubios is consistent. Everywhere I've had it i... 2015-05-09 02:44:37
# 3700001  Meh. \n\nChipotle is way better. Qdoba is way ... 2016-06-28 04:55:28
# 3700002  Kelley has done my brows 3 times now and I am ... 2015-02-27 16:31:23
# 3700003  I decided that it was time to break free of th... 2012-09-28 12:43:33
# 3700004  Very happy with arrangement I got for my wife'... 2014-09-17 04:52:12
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 3800000  d17LFDbft1-n2LsIGWl-AA  yKblUwUkHKZP_u9qZYw5pg
# 3800001  O8RDAT89_R_aL892Bl0lMg  NQkc_ldx-a9kxgN8zL9IKA
# 3800002  6hWPaBkEXm2TnBYlISVTZw  StJmL4kXXt67kzjVVS3R2Q
# 3800003  lSHtsqGO5l-tO-xt1N2rtQ  Y3AQwNRmauhqGkZ4GudpSg
# 3800004  f9LhIBubnDoUPdhOci5Osg  W5ztWhE4LaA7nyhAeiWmUA
#
#                     business_id  stars  useful  funny  cool  \
# 3800000  VkAhWzmhMTCQDMoedhI8Vg      2      10      2     0
# 3800001  TzkVUJab9Sh0CqDk2sCF-w      5       1      0     0
# 3800002  stqWlKEgXweNQSsxOsHjVA      4       1      0     0
# 3800003  NSsXMFzmmpiF9V5Nqcmvdw      5       0      0     0
# 3800004  7pwFfnB6FH4lflXWrQ2Tqw      3       0      0     0
#
#                                                       text                date
# 3800000  I'm giving them 2 stars ONLY because they do s... 2016-07-13 22:44:18
# ...
# 5700002  buWkt6p8Ns5Xr1pcbe0ORQ  az1JWTD01hFJ2Q7bnknXbw
# 5700003  0KKwY8rNKnUVbkqchtOd6w  dxJhWkSns2VDqC_-Hw-dTQ
# 5700004  G8TMe0-cN2luUViH7hdvjg  fuLoRVzjPwObGnR8O2qyEA
#
#                     business_id  stars  useful  funny  cool  \
# 5700000  TNTBObKmICMn13T0pyAGyg      5       0      0     0
# 5700001  GG-DeOjnmu4V_opx-MIfvA      3       3      0     0
# 5700002  D_CMgRM8nnE94i_newJi9g      4       1      1     0
# 5700003  NnIrd_1O9QyuCLigoxYv3g      5       1      0     0
# 5700004  WY7Umhuv9jcQ6fOoOFa4lQ      5       1      0     1
#
#                                                       text                date
# 5700000  Just leaving and I have to say, the team here ... 2018-05-13 00:46:20
# 5700001  Went on a girls night out. First time trying i... 2010-07-17 05:37:19
# 5700002  Decent customer service, tasty food, reasonabl... 2013-09-12 20:26:15
# 5700003  If you "do not drink IPA's", you must try them... 2018-02-27 16:10:30
# 5700004  Very good food. Had a great meal - recommend t... 2018-06-23 21:09:35
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 5800000  ar5Xy4FZLviv-xFxEUiWlQ  Pc0Keed-RgXSlyd4BXhb5g
# 5800001  izBBz4xTXbPNRLs2TVOosQ  yQuwIjZeKJIZDiIitsIENQ
# 5800002  J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 5800003  9DI78aMAjEVNLLuZ8K9Bjw  MwOk88w7W-Ok6g-KzCGpCA
# 5800004  NT3T9R2iuos5VF2Bb6nmdw  KCMhTqFOtxlyroerv-MQAA
#
#                     business_id  stars  useful  funny  cool  \
# 5800000  nR3VW9i2K8033QY0ZMTisw      4       0      0     0
# 5800001  zI_io7SVTzU9fNOpqcKNdA      4       1      0     1
# 5800002  yPSejq3_erxo9zdVYTBnZA      5       0      0     0
# 5800003  qOrd_jWT3e16_wwRSpvYwQ      4       0      0     0
# 5800004  z31te0YMSegTdktp3qYqGw      4       0      0     0
#
#                                                       text                date
# 5800000  I'm obsessed with sushi and could eat it every... 2016-05-16 20:28:03
# 5800001  Want a great ice cream cone? Look no further t... 2016-10-24 23:13:25
# 5800002  This is the best Mexico food I ever had. I and... 2018-08-22 19:58:57
# 5800003  Nice ambience, friendly staff. Food was good, ... 2014-12-15 18:18:20
# 5800004  Ate here last night for my Birthday.  I love g... 2011-02-03 02:36:07
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 5900000  0z8E476JaG4vga_1gqyQKA  CT6fLhF_uRYYwMfzDuRxOQ
# 5900001  G163rZ96A9tjLcgiTGeSEQ  NdquBac4xdSnlBcoTLRNqg
# 5900002  0YEH702dZzTTs-XlYVG7HA  Y7fbrXoz8zFUp387BkZCnA
# 5900003  5b20KJuFSeppVZtyIgPbOQ  Bjrgm4RpggnuwIgM8pgdZA
# 5900004  04dGU-Wr8quCHhkqTJvbrA  zAMpV0uFt9XpqRDFNLWPrQ
#
#                     business_id  stars  useful  funny  cool  \
# 5900000  K0oRQuRcTkrS-sQlfH5JMA      5       1      0     0
# 5900001  kburcuSQtWvwI4cA44reDg      5       0      0     0
# 5900002  SZNPeRSJ48mm77aXqfUbCw      4       0      0     0
# 5900003  vaoSpYVAFXLvRfJGK1IF2g      4       0      0     0
# 5900004  smLHa_Hi6Dl_PtrxQRahSQ      5       6      1     0
#
#                                                       text                date
# 5900000  We came in an hour before close and we're the ... 2018-06-15 01:05:32
# 5900001  What a great experience!  We're new to the are... 2012-06-11 19:11:28
# 5900002  I've been to quite a few home Goods must say s... 2018-08-29 08:57:18
# 5900003  Friendly local place. You could go to Starbuck... 2010-07-30 01:06:02
# 5900004  i COULD NOT stop eating that Huge pile of Gizz... 2009-11-29 03:59:32
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6000000  LEt_rcvZ9UsAhQCRGRBkVQ  rWQaJXlszSGjbpeOhc6MpA
# 6000001  nfHyQfb1oTTvGevA0JrqNg  M0N8g7gkV4bkjUDRsyZKTA
# 6000002  K4gdzC3ut1SJAkHWR_YGQQ  7YtZgk47gwcUZZSc68_41A
# 6000003  7hGVG9nUzhpiiSAniPDTbg  iExzs4voEa1-N0bSYODg1A
# 6000004  1z_2diaMLhSkc0z4L0BxnQ  6AI8lK1tnlOjoWF0qpLyog
#
#                     business_id  stars  useful  funny  cool  \
# 6000000  dAZASdppYH5DQvXLlzGiow      4       1      1     0
# 6000001  PhO1GC_o2DbOIlbODRiu1w      4       0      0     0
# 6000002  QA8QLpwf_YT9C2ST5YJ0vw      1       0      0     0
# 6000003  zropQGh2fc7PMpzd32vneQ      3       2      0     2
# 6000004  ramBBnf8_ZAZ16aUnSUMJg      2       3      0     0
#
#                                                       text                date
# 6000000  Very good food here!  Casual dining in the Don... 2017-05-12 23:58:29
# 6000001  I've been here twice and was generally pleased... 2019-02-18 21:34:37
# 6000002  The bar 33 is nice but restaurant overrated, h... 2016-05-15 05:00:45
# 6000003  The place is located inside the new China Town... 2017-04-06 23:17:53
# 6000004  Ordered Chicken Fried Rice. Rice was not fried... 2018-11-27 02:18:43
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6100000  nTXeL7DUXYc0fCP9-IN9MA  PDqZcpc3AyqODXriY-sJMg
# 6100001  bXmypAkYPExTzynfT4PpTw  PWAEXFV60GpZU89SYj0fLA
# 6100002  F1M0NI3w9X9eLeSrJpIsFA  phZwe9S6qrDtxwPRolKn6A
# 6100003  JwpLP55IXmInZacS8mIKSg  u2a5EoQ9Uvmg849GNHghOg
# 6100004  Y9ySOXjIbWk6MhtuFAvWtw  ZkSDxgdZek2dbiw8rLRsIw
#
#                     business_id  stars  useful  funny  cool  \
# 6100000  d48Xrx8MhGtdaLvhcYzNWQ      5       0      0     0
# 6100001  xTVYKKFt7tKfpKj5nzUSSQ      5       0      0     0
# 6100002  tQIw_BZzfjh8UC4Eqhd0XQ      5       0      0     0
# 6100003  FrKhPnv38j2tjGBvBWBPyQ      1       4      0     0
# 6100004  a6z7dJX3k1AUsC7rSoH_Mw      1       5      2     0
#
#                                                       text                date
# 6100000  BEST Bun Bo Hue in Philly.  They are still in ... 2020-09-18 05:25:42
# 6100001  Amazing! I went for my first few appointments ... 2020-11-13 21:13:15
# 6100002  Self proclaimed beach bum here. Very clean and... 2020-11-23 14:58:23
# 6100003  I thought it was going to be a good company. I... 2020-07-14 10:51:53
# 6100004  I got the following response from Diamondback ... 2016-03-13 06:45:08
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6200000  kMtPqQKygCEXM_qXROX6MA  LL48slXTkK_s4nU-ORdvkw
# 6200001  ktDTwN4JEEjbzI5RisvQUg  rofxMGVHXoaHDB8zmH1PFA
# 6200002  JmrmFFbqL5MC8NH8yBGTOA  DwaaafwryFbW7C4E1gU1AA
# 6200003  CW2rbLjXrSnI7a8EwU7V3w  _8OVGplSDWlzglh6XgLNzw
# 6200004  dOBmv7kiHI15oU_DfYCkdA  P1hlXpjRldmaoBSLi2oHNA
#
#                     business_id  stars  useful  funny  cool  \
# 6200000  LkIu_SL2mlZfbxgiH8rmsQ      1       0      0     0
# 6200001  Sad6etx6kKYxrpvWcd11MA      1       1      0     0
# 6200002  NSx1sbvSzPprLn9RJuRdQw      3      23      8    19
# 6200003  yPSejq3_erxo9zdVYTBnZA      5       0      0     0
# 6200004  iksVwRfpWymIUUFqw0tXpw      5       3      1     2
#
#                                                       text                date
# 6200000  I paid way over MSRP for a new Subaru legacy w... 2021-09-29 18:26:18
# 6200001  Check your drinks!!! Me and 3 of my friends we... 2019-11-23 23:07:57
# 6200002  A small studio like theater at the corner of W... 2019-01-06 07:06:29
# 6200003  DEFINITELY RECOMMEND THIS PLACE. Delicious, DE... 2021-09-30 23:54:04
# 6200004  Finally!!! A good hotpot spot in philly! The c... 2019-04-17 02:21:26
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6300000  HKFIBV9rs9-GtE0YCiprJg  KXX_KFF_TS2cKrg2_2RfSA
# 6300001  s5GA5xqAE1WKZE_GJNq_uQ  uPRG5l1Ztd9TT03FR4XX0w
# 6300002  6EMHiavfn7e2COCauFFP5Q  BadPxhjKb8N-nZNdPnpC-w
# 6300003  KjcoEQCCgE7qY0y4YF7mYw  b6SwwUOqrGE3mM_awI4SoQ
# 6300004  cwqc6fvJeo5ZKo7CBQ1Ymg  fTKdyc-GV9VResVjqXtehQ
#
#                     business_id  stars  useful  funny  cool  \
# 6300000  NC2cV1pPDs3MYeGM5LFsag      3       0      0     0
# 6300001  7h-gAKxe_KqA5EDGCT4C2A      2       0      0     0
# 6300002  UesqLOoyOGPQsonHpMb59g      2       1      0     0
# 6300003  THJ0i8yRyx1OfvzLsJXgng      5       2      0     0
# 6300004  zr-b0_ARdeb5eTLHemB5yQ      1       1      0     0
#
#                                                       text                date
# 6300000  No real complaints. Ordered a green power smoo... 2015-01-03 23:09:19
# 6300001  Possibly the most convenient location ever for... 2015-06-08 19:22:53
# 6300002  My first time getting eye lash extensions I wa... 2017-05-13 15:40:44
# 6300003  Fantastic options for beer lovers, vegetarians... 2016-01-04 03:34:02
# 6300004  We were shopping all day Monday in Philadelphi... 2016-10-26 15:26:57
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6400000  qcz8aj8rndr6J9_0V95OIg  ZAkT0_fDzmH0a8rzon8dEg
# 6400001  R-EI4JFdtI9F93QDT16R6A  F7HPo-1dtqiQatjmpa-YHQ
# 6400002  s-J5GW9RFHRDS-VCVPdV3w  onBtzYEboBIBFKjvVHF15A
# 6400003  VoWrHWl-bT-gCoi1X79xxQ  dc5ftrZRDivg365ej1Y9lg
# 6400004  x_p2zlrBAiHiml0xCyf22g  t7npN2I8kbKLZOexC4jAtA
#
#                     business_id  stars  useful  funny  cool  \
# 6400000  SxbqEgEwrGmtgvQAgM6kIg      1       4      2     1
# 6400001  aunmz06iWvo3bd6MMHEbqg      3       0      0     1
# 6400002  GnUCr3D7a0wqp0S-twXmqg      4       0      1     0
# 6400003  guwb1zuNEMtJVproo0ntFw      3       3      1     0
# 6400004  9r647m5zhYMt0WB5MZRrVw      5       0      0     0
#
#                                                       text                date
# 6400000  Wow where do I start?  The ridiculously small ... 2015-01-07 22:33:51
# 6400001  3 stars because the staff is nice & I love the... 2012-12-14 04:04:48
# 6400002  If you need an inexpensive tire fix this is on... 2017-06-09 21:30:54
# 6400003  Okay.. let me explain.\n\nFood: 5 stars, 10 st... 2012-11-21 00:56:43
# 6400004  Unlike the experience I had at a local Labcorp... 2017-02-03 14:23:06
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6500000  0b-FTVyegQDMLfnVsrmwxw  f4mbT-nxg2AJhqxB6XgnlA
# 6500001  cxKtq-hLET-WCMUX2iK2SA  doYtRkbRhCsuzrl0z0Y-uQ
# 6500002  jorwq46jWZoJzhYo2o5IwA  GJUP_9KUzyLs47QUWDxFhA
# 6500003  pFFtwzKciD3vyRLxL0XUAA  KtC_4XlJU5kpnUtTfB2cEQ
# 6500004  Vdgg_OW_LwgkeC2SNE2p9A  1eYceZg_Hfexsjm2g0E_uA
#
#                     business_id  stars  useful  funny  cool  \
# 6500000  1AVczg8ZmLaFhOJdrp4pPA      5       1      0     0
# 6500001  BmwHAMrY-Tdrz6PApscqEg      4       3      2     2
# 6500002  mU_iRT-NtND82T6xar7UxQ      5       3      4     2
# 6500003  mIUt2ZiDeH1lUXQQ95thMg      5       1      0     0
# 6500004  V2mnF894UEjR53dhf9qS1Q      2       0      0     0
#
#                                                       text                date
# 6500000  So, you need roller skates to see it all in he... 2013-11-18 17:38:02
# 6500001  Fan of the gyro?  Or perhaps searching for a g... 2010-07-14 14:19:32
# 6500002  Mad Art = Hidden St. Louis Gem.\n\nStill with ... 2012-02-08 08:09:30
# 6500003  I recently attended a fabulous wedding at the ... 2015-09-03 08:27:46
# 6500004  I needed a quick lunch on the go while running... 2012-10-17 19:33:37
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6600000  uJHupxp39SNF4SBPGQunEw  5hRcYPjUQCnLkzXerD7E6g
# 6600001  doXRe2VjG6YUrcETtNKEyA  inI7G_hquFr7_d4nXF7X-g
# 6600002  8wnJ_4cOBEvBg7oHrEAkhQ  2XFpcnga2CpIC9YioVmNeg
# 6600003  Da-2VCFm1_M1Xp2eFIhwMA  -wlAGGA2fqFjIvO-SKU9Lw
# 6600004  83MYBF5V53MKupXlzeXSBw  tmmIjOUg9f86jU84swq-8g
#
#                     business_id  stars  useful  funny  cool  \
# 6600000  ZmJmr1cp0-4M7jdDT5v_QA      5       4      1     0
# 6600001  eBrjs8r9JXwv99dRvAAQFQ      3       2      3     0
# 6600002  xkWhyrBL0i_P8YdXGJ2iUg      5       6      5     6
# 6600003  ELGdPtyfE_zC10VYc6Zskw      3       0      0     0
# 6600004  MFngbjvbrLnLl7j-zBO2sg      5       1      1     2
#
#                                                       text                date
# 6600000  This afternoon I had a restorative and Reiki s... 2014-06-10 21:06:01
# 6600001  Trampolines... Check.      Lots of kids.... Ch... 2012-12-28 00:08:10
# 6600002  An absolute must do in NOLA, second only to li... 2015-05-08 07:24:10
# 6600003  It's ok, but I expected more.   The bacon chee... 2012-02-20 23:05:10
# 6600004  Okay do I even need to explain why this place ... 2017-05-06 02:25:56
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6700000  cthmEBno2lArdfm18kLTgg  7wu3MKmjMSObsACfWS-9Lg
# 6700001  MKu-P0cQ6-orf-knG_obHw  6U1aQX49jcfB1RBjiah3TA
# 6700002  TKdUz48pblf7yWcKoao_FA  xCDQVvvLdYw9bT4gHTexlg
# 6700003  Dvmab2ccBwxCo-Xfo7Iqdw  nnwBdqGHIAJQ5QX9lHOtrQ
# 6700004  SgNrAanfRhubIj60gaLsJg  avQwKRvXc21koLCbahFEig
#
#                     business_id  stars  useful  funny  cool  \
# 6700000  SmSNWxjEYQgpn-uH7Qfv7A      4       0      0     0
# 6700001  BZNqCyMhZJREF8rfmrZ2bA      5       0      0     0
# 6700002  i3vAyiOJlHFBLWcQil3z9Q      1       3      1     1
# 6700003  tdCWwSbMXBHomFe1aILUgw      2       0      1     0
# 6700004  mK5gu18whrKEG8aojSzpbA      4       2      0     2
#
#                                                       text                date
# 6700000  Came here for the first time today the food wa... 2016-03-01 21:02:57
# 6700001  Go. Stop reading this and GO. Right now. Went ... 2018-05-15 02:22:04
# 6700002  Borel's disabled my ability to respond to MY o... 2016-01-12 16:59:20
# 6700003  While they aren't the best service I've had (T... 2009-01-29 21:30:40
# 6700004  As far as the Philly offerings for froyo goes,... 2009-09-22 21:51:51
# Procesando 100000 filas.
#                       review_id                 user_id  \
# 6800000  3WDQwJKHm5cb_MHKftGv6Q  SSpW_pdkzCCno7uIOWou_A
# 6800001  4Pt7XZC7VzpSZtcNEKsEOQ  4sQ90eG7IKphXn2KOPboxQ
# 6800002  prZC1d5zm0jzXVFlUt7N0g  kOOwOvOZ0__KqVQxEq-oOg
# 6800003  B8UPvV8ZARVCsYRwuTzTAw  BewDV2ISn0uAMLcsyrhiZg
# 6800004  aGHUz5yMJgnHx67sUhOU_w  1hWcqve-JYonJYEMmfS5EQ
#
#                     business_id  stars  useful  funny  cool  \
# 6800000  PEkt4TW5RU4BZoI_-hBTVA      1       1      0     0
# 6800001  A2g4xVndUjK-Qv9P60cAxQ      5       0      0     0
# 6800002  4RNZxB_UfRY6xmCHGwd18Q      1       2      1     0
# 6800003  vhGl4WDtyvSd1Ml0b_FaFA      4       0      0     0
# 6800004  wRBKMzEV9bUqjGWH0Vd8Fg      2       0      0     0
#
#                                                       text                date
# 6800000  DO not even think of swithching to Comcast/Xfi... 2020-07-08 20:59:05
# 6800001  I have been taking my Toyotas to LTS for years... 2020-10-16 15:28:06
# 6800002  Coming here for Cinco de Mayo, I had high hope... 2019-05-05 19:13:35
# 6800003  We were so glad to finally check this restaura... 2020-12-30 19:09:10
# 6800004  bar was covered in dozens of bees. bartenders ... 2020-12-24 05:41:46
# Procesando 90280 filas.
#                       review_id                 user_id  \
# 6900000  BLu89xFjBFjcFB11ExqmbA  N3_CVCqI9bBVdrynd2KZVw
# 6900001  0-JvMzZV1sy8mN5-b4mKng  nUbcXBO4tLHlm0SUHy9Qig
# 6900002  yiBzu4GfyABEBImLR62uAw  _pNerxa8_oa2rGSsK8sckw
# 6900003  wb3B-fwzK0JItr5spJMxLg  OIaACBkKofGy1QJw8hOYTg
# 6900004  Qr_trHV78rMtTWJgTJhwEw  eWDVAz99_h2dSef6VF0Gzw
#
#                     business_id  stars  useful  funny  cool  \
# 6900000  jh8j-DWqgWkbRe_a2XtKFQ      5       0      0     0
# 6900001  lhiaIa2-FkK1k5k-BeMxhg      5       3      0     0
# 6900002  U1Gc3wKN5viu_e68KJVOdQ      5       3      1     2
# 6900003  _OxsSJLOrhdJq3-EewouvQ      5       0      0     0
# 6900004  Bg7D8LrsW9XbYlEhT9yekw      1       0      0     0
#
#                                                       text                date
# 6900000  Terrific place, I've known some of the staff f... 2020-12-17 02:02:53
# 6900001  My previous dentist died from a fast moving ca... 2018-07-06 01:14:47
# 6900002  When it's 10PM on a Friday during COVID times,... 2021-01-09 17:03:54
# 6900003  Dane was outstanding and worked very hard to m... 2021-08-10 23:28:42
# 6900004  Very small was looking for the Van Gogh exhibi... 2021-08-11 00:49:25

# %%
# Contar valores nulos por columna
null_counts =chunk .isnull().sum()
print("Valores nulos por columna:")
print(null_counts)
# Out:
# Valores nulos por columna:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
# Contar filas duplicadas
duplicate_counts = chunk.duplicated().sum()
print(f"Cantidad de filas duplicadas: {duplicate_counts}")
# Out:
# Cantidad de filas duplicadas: 0

# %%
# Ver tipos de datos de las columnas
print("Tipos de datos por columna:")
print(chunk.dtypes)
# Out:
# Tipos de datos por columna:
# review_id              object
# user_id                object
# business_id            object
# stars                   int64
# useful                  int64
# funny                   int64
# cool                    int64
# text                   object
# date           datetime64[ns]
# dtype: object

# %%
# 1. Estadísticas descriptivas para columnas numéricas
desc_stats = chunk[['stars', 'useful', 'funny', 'cool']].describe()

print("Estadísticas descriptivas:")
print(desc_stats)

# 2. Distribución de frecuencias de las estrellas
star_counts = chunk['stars'].value_counts()

print("\nDistribución de frecuencias de las estrellas:")
print(star_counts)

# 3. Ver correlación entre los votos útiles, graciosos y cool
correlation = chunk[['useful', 'funny', 'cool']].corr()

print("\nCorrelación entre votos útiles, graciosos y cool:")
print(correlation)
# Out:
# Estadísticas descriptivas:
#               stars        useful         funny          cool
# count  90280.000000  90280.000000  90280.000000  90280.000000
# mean       3.610933      1.769373      0.482632      0.826595
# std        1.622845      4.785276      2.427570      3.464703
# min        1.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000
# 50%        4.000000      1.000000      0.000000      0.000000
# 75%        5.000000      2.000000      0.000000      1.000000
# max        5.000000    392.000000    288.000000    304.000000
#
# Distribución de frecuencias de las estrellas:
# stars
# 5    43323
# 1    19427
# 4    13910
# 3     7073
# 2     6547
# Name: count, dtype: int64
#
# Correlación entre votos útiles, graciosos y cool:
#           useful     funny      cool
# useful  1.000000  0.653141  0.792367
# funny   0.653141  1.000000  0.763812
# cool    0.792367  0.763812  1.000000

# %% [markdown]
# 1. Estadísticas descriptivas:
#  * Se proporcionan estadísticas descriptivas para las columnas 'stars', 'useful', 'funny' y 'cool'.
#  * count: El número total de observaciones (reseñas) es de 90280.
#  * mean: El promedio de estrellas es de 3.61, lo que indica que, en promedio, las reseñas tienen una calificación relativamente alta. El promedio de votos útiles es de 1.77, el de votos graciosos es de 0.48 y el de votos cool es de 0.83.
#  * std: La desviación estándar mide la dispersión de los datos. La desviación estándar de las estrellas es de 1.62, lo que indica que hay cierta variabilidad en las calificaciones. La desviación estándar de los votos útiles, graciosos y cool es relativamente alta, lo que indica que hay una gran variabilidad en el número de votos de cada tipo.
#  * min: El valor mínimo para todas las variables es 0, excepto para las estrellas, que es 1.
#  * 25%, 50%, 75%: Estos son los percentiles, que indican el valor por debajo del cual cae un cierto porcentaje de los datos. Por ejemplo, el 50% de las reseñas tienen 4 o menos estrellas, el 50% de las reseñas tienen 1 o menos votos útiles, 0 votos graciosos y 0 votos cool.
#  * max: El valor máximo de estrellas es 5. Los valores máximos para votos útiles, graciosos y cool son 392, 288 y 304, respectivamente, lo que indica que hay algunas reseñas con un número excepcionalmente alto de votos.
#  2. Distribución de frecuencias de las estrellas:
#  * Se muestra la distribución de frecuencias de las estrellas.
#  * La mayoría de las reseñas tienen 5 estrellas (43323).
#  * Un número significativo de reseñas tienen 1 estrella (19427).
#  * No se muestran las frecuencias de 2, 3 y 4 estrellas, pero se puede inferir que son menores que las de 1 y 5 estrellas.

# %%
# Filtrar las columnas relevantes (por ejemplo, 'stars', 'useful', 'funny', 'cool')
df_reviews_filtered = chunk[['stars', 'useful', 'funny', 'cool']]

# Método 1: Usar el rango intercuartílico (IQR) para detectar valores atípicos
Q1 = df_reviews_filtered.quantile(0.25)
Q3 = df_reviews_filtered.quantile(0.75)
IQR = Q3 - Q1

# Definir límites de los valores no atípicos
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Detectar los valores atípicos
outliers_iqr = df_reviews_filtered[(df_reviews_filtered < lower_bound) | (df_reviews_filtered > upper_bound)]

# Mostrar los valores atípicos
print("Valores atípicos detectados con IQR:")
print(outliers_iqr.dropna())

# Método 2: Usar desviación estándar
mean = df_reviews_filtered.mean()
std_dev = df_reviews_filtered.std()

# Valores atípicos fuera de 3 desviaciones estándar
outliers_std = df_reviews_filtered[(df_reviews_filtered < (mean - 3 * std_dev)) | (df_reviews_filtered > (mean + 3 * std_dev))]

# Mostrar los valores atípicos
print("Valores atípicos detectados con desviación estándar:")
print(outliers_std.dropna())
# Out:
# Valores atípicos detectados con IQR:
# Empty DataFrame
# Columns: [stars, useful, funny, cool]
# Index: []
# Valores atípicos detectados con desviación estándar:
# Empty DataFrame
# Columns: [stars, useful, funny, cool]
# Index: []

# %%
# Histograma de la columna 'stars'
plt.figure(figsize=(6, 3))
sns.histplot(df_reviews_filtered['stars'], bins=5, kde=False, color='skyblue', edgecolor='black')
plt.title('Histograma de la columna "stars"')
plt.xlabel('Puntaje en estrellas')
plt.ylabel('Frecuencia')
plt.xticks([1, 2, 3, 4, 5])  # Asegurar que se muestren los valores de estrellas 1 a 5
plt.show()

# Boxplot para las columnas 'useful', 'funny' y 'cool'
plt.figure(figsize=(6, 3))
sns.boxplot(data=df_reviews_filtered[['useful', 'funny', 'cool']])
plt.title('Boxplot de las columnas "useful", "funny" y "cool"')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# * El histograma muestra que la distribución de las estrellas no es uniforme. Hay una alta frecuencia de puntajes de 5 estrellas, lo que sugiere que la mayoría de las reseñas tienen calificaciones altas.
#  * La frecuencia de 1 estrella también es relativamente alta, lo que indica que también hay un número significativo de reseñas con calificaciones bajas.
#  * Las frecuencias de 2, 3 y 4 estrellas son mucho más bajas, lo que indica que hay menos reseñas con calificaciones intermedias.
#  * La distribución parece estar sesgada hacia la derecha, con una cola larga hacia la izquierda

# %% [markdown]
# cada boxplot muestra la distribución de una variable. El boxplot muestra la mediana, los cuartiles, los valores atípicos y el rango de la variable.
# Análisis:
#  * Los boxplots muestran que las tres variables tienen una distribución asimétrica, con una cola larga hacia la derecha.
#  * Hay valores atípicos en las tres variables, lo que indica que hay algunas reseñas que tienen muchos votos útiles, graciosos o geniales.
#  * La mediana de "funny" es la más baja, lo que sugiere que la mayoría de las reseñas no se consideran graciosas.
#  * La mediana de "useful" es ligeramente más alta que la de "cool", lo que sugiere que las reseñas tienden a ser consideradas más útiles que geniales.
#  * La dispersión de los datos (el rango intercuartílico) es mayor para "useful" y "cool" que para "funny", lo que indica que hay más variabilidad en el número de votos útiles y geniales que en el número de votos graciosos.
# Posibles conclusiones e implicaciones:
#  * Los votos útiles y geniales tienden a ser más comunes que los votos graciosos.
#  * Hay algunas reseñas que son excepcionalmente útiles, graciosas o geniales.

# %%
# Gráfico de dispersión entre 'stars' y 'useful'
plt.figure(figsize=(8, 4))
sns.scatterplot(x='stars', y='useful', data=df_reviews_filtered, color='blue', alpha=0.6)
plt.title('Dispersión entre Estrellas y Votos Útiles')
plt.xlabel('Estrellas')
plt.ylabel('Votos Útiles')
plt.show()

# Gráfico de dispersión entre 'stars' y 'funny'
plt.figure(figsize=(8, 4))
sns.scatterplot(x='stars', y='funny', data=df_reviews_filtered, color='orange', alpha=0.6)
plt.title('Dispersión entre Estrellas y Votos Graciosos')
plt.xlabel('Estrellas')
plt.ylabel('Votos Graciosos')
plt.show()

# Gráfico de dispersión entre 'stars' y 'cool'
plt.figure(figsize=(8, 4))
sns.scatterplot(x='stars', y='cool', data=df_reviews_filtered, color='green', alpha=0.6)
plt.title('Dispersión entre Estrellas y Votos Cool')
plt.xlabel('Estrellas')
plt.ylabel('Votos Cool')
plt.show()

# Correlación entre 'stars' y los votos
correlation = df_reviews_filtered[['stars', 'useful', 'funny', 'cool']].corr()
print(correlation)
# Out:
#            stars    useful     funny      cool
# stars   1.000000 -0.043639 -0.009626  0.093218
# useful -0.043639  1.000000  0.653141  0.792367
# funny  -0.009626  0.653141  1.000000  0.763812
# cool    0.093218  0.792367  0.763812  1.000000

# %% [markdown]
# El gráfico de dispersión muestra la relación entre "Estrellas" y "Votos Útiles". Se observa una tendencia positiva, lo que significa que a medida que aumenta el número de estrellas, también tiende a aumentar el número de votos útiles.
#  * Dispersión: Hay una gran dispersión en los datos, lo que significa que hay muchas observaciones que no siguen la tendencia general. Sin embargo, la tendencia positiva es aún evidente.
#  * Valores atípicos: Se pueden observar algunos valores atípicos, como el punto con un valor de "Votos Útiles" alto para un valor de "Estrellas" bajo (2.0) y los puntos con valores de "Votos Útiles" altos para valores de "Estrellas" altos (5.0).

# %% [markdown]
# * El gráfico muestra la dispersión de los datos, lo que permite visualizar si existe alguna relación entre las dos variables.
#  * A diferencia del gráfico anterior que mostraba la relación entre estrellas y votos "cool", este gráfico muestra una relación menos clara entre estrellas y votos graciosos.
#  * No parece haber una tendencia fuerte entre las dos variables. Hay una gran dispersión en los datos, lo que significa que no hay una relación evidente entre el número de estrellas y el número de votos graciosos.
#  * Se pueden observar grupos de puntos en ciertos rangos de estrellas, pero estos grupos no muestran una tendencia clara.
#  * Para valores de estrellas bajos (1.0 y 2.0), los votos graciosos tienden a ser bajos.
#  * Para valores de estrellas más altos (3.0 y 4.0), se observa una mayor variedad en los votos graciosos, pero no hay una tendencia clara hacia valores más altos.
#  * Hay un punto atípico con un valor de votos graciosos alto para un valor de estrellas bajo (1.0).

# %% [markdown]
# * El gráfico muestra la dispersión de los datos, lo que permite visualizar si existe alguna relación entre las dos variables.
#  * En general, parece haber una tendencia positiva entre "Estrellas" y "Votos Cool". A medida que aumenta el número de estrellas, también tiende a aumentar el número de votos cool.
#  * Sin embargo, la relación no es perfecta. Hay una gran dispersión en los datos, lo que significa que hay muchas observaciones que no siguen la tendencia general.
#  * Se pueden observar grupos de puntos en ciertos rangos de estrellas, lo que sugiere que hay categorías o subgrupos dentro de los datos.
#  * Para valores de estrellas bajos (1.0 y 2.0), los votos cool tienden a ser bajos.
#  * Para valores de estrellas más altos (3.0 y 4.0), se observa una mayor variedad en los votos cool, con algunos valores altos.
#  * No hay puntos con valores de estrellas superiores a 4.5.

# %%
# Contar el número de reseñas por usuario
reviews_per_user = chunk.groupby('user_id').size()

# Mostrar los 10 usuarios más activos
top_users = reviews_per_user.sort_values(ascending=False).head(10)
print(top_users)

# Promedio de estrellas por usuario
avg_stars_per_user = chunk.groupby('user_id')['stars'].mean()
top_users_avg_stars = avg_stars_per_user.sort_values(ascending=False).head(10)
print(top_users_avg_stars)
# Out:
# user_id
# ET8n-r7glWYqZhuR6GcdNw    114
# bJ5FtCtZX3ZZacz2_2PJjA    102
# pou3BbKsIozfH50rxmnMew     83
# WwulXySQN8t2hwqH_yWurA     45
# 5O3VvfDu_HDvgUviAqmTEA     45
# -G7Zkl1wIWBBmD0KRy_sCw     41
# ppsm8EDKjA1fp1yTCP3RrQ     40
# 6s-g2vFu12OemhiK3FJuOQ     37
# NNgQ8fV5ARQgHw-Ob7l50A     35
# fr1Hz2acAb3OaL3l6DyKNg     35
# dtype: int64
# user_id
# zzcSgjfQjgB2nE-n2zCVMQ    5.0
# zzUdRyz7uebYI4t5z4Snmg    5.0
# --7XOV5T9yZR5w1DIy_Dog    5.0
# --8MBM8RDdd-A0XVK4yxvQ    5.0
# zyfQkC4UITOpJNC1mLzm_A    5.0
# zyab2qsMarU5bGjhRL7syw    5.0
# zyUJQ-RGG7cYnDu8AqVm_Q    5.0
# zyDj0-XUYM3rEi4VWK-hKw    5.0
# zy8MURJjVgDB8c9i9rzr5A    5.0
# zy4O-1FsY3-2aigfhK_CYQ    5.0
# Name: stars, dtype: float64

# %%
# Graficar los 10 usuarios más activos
top_users.plot(kind='bar', color='skyblue')
plt.title('Top 10 Usuarios Más Activos')
plt.xlabel('User ID')
plt.ylabel('Número de Reseñas')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  * El gráfico permite una comparación visual rápida de la actividad entre los diferentes usuarios. Es evidente que algunos usuarios son significativamente más activos que otros.
#  * El usuario representado por la primera barra (a la izquierda) es el más activo.
#  * A medida que se avanza hacia la derecha en el eje X, la altura de las barras disminuye, lo que indica una disminución en la actividad de los usuarios

# %%
# Contar el número de reseñas por negocio
reviews_per_business = chunk.groupby('business_id').size()

# Graficar la distribución de reseñas por negocio
plt.figure(figsize=(12, 6))
reviews_per_business.sort_values(ascending=False).head(20).plot(kind='bar', color='skyblue')
plt.title('Top 20 Negocios con Más Reseñas')
plt.xlabel('Business ID')
plt.ylabel('Número de Reseñas')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# El gráfico permite una comparación visual rápida del número de reseñas entre los diferentes negocios. Es evidente que algunos negocios tienen significativamente más reseñas que otros.
#  * El negocio representado por la primera barra (a la izquierda) tiene la mayor cantidad de reseñas.
#  * A medida que se avanza hacia la derecha en el eje X, la altura de las barras disminuye, lo que indica una disminución en el número de reseñas.

# %%
# Graficar la distribución de puntajes por negocio (top 10)
plt.figure(figsize=(12, 6))
sns.boxplot(x='business_id', y='stars', data=chunk[chunk['business_id'].isin(reviews_per_business.head(10).index)])
plt.title('Distribución de Estrellas por Negocio (Top 10)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Variabilidad en las Calificaciones: Se observa una variabilidad significativa en las calificaciones de estrellas entre los diferentes negocios. Algunos negocios tienen una distribución de calificaciones más amplia, mientras que otros tienen una distribución más estrecha.
#  * Negocios con Calificaciones Altas: Algunos negocios (por ejemplo, "XLN - V6MVZMg2A") muestran una distribución de calificaciones más alta, lo que indica que tienden a recibir calificaciones más altas de manera consistente.
#  * Negocios con Calificaciones Bajas: Otros negocios (por ejemplo, "T2dR6BNvQ2Tnw") muestran una distribución de calificaciones más baja, lo que indica que tienden a recibir calificaciones más bajas de manera consistente.
#  * Presencia de Valores Atípicos: Algunos negocios muestran valores atípicos (puntos fuera de los bigotes de las cajas). Estos valores atípicos representan calificaciones inusualmente altas o bajas que podrían indicar experiencias excepcionales o problemas específicos.
#  * Comparación de Mediana: La línea dentro de cada caja representa la mediana de las calificaciones. Comparar las medianas entre los negocios puede ayudar a identificar qué negocios tienen calificaciones promedio más altas o más bajas.

# %%
# Convertir la columna 'date' a formato de fecha
chunk['date'] = pd.to_datetime(chunk['date'])

# Extraer el año y el mes de la fecha
chunk['year_month'] = chunk['date'].dt.to_period('M')

# Agrupar por año y mes y calcular el promedio de 'stars'
monthly_avg_stars = chunk.groupby('year_month')['stars'].mean()

# Graficar el promedio de estrellas por mes
plt.figure(figsize=(12, 6))
monthly_avg_stars.plot(kind='line', color='green', marker='o')
plt.title('Promedio de Puntajes de Estrellas por Mes')
plt.xlabel('Fecha (Año-Mes)')
plt.ylabel('Promedio de Estrellas')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Tendencia Decreciente: Se observa una tendencia general decreciente en el promedio de estrellas a lo largo del tiempo. Al principio, en 2007, el promedio de estrellas era relativamente alto (cercano a 4.5), pero luego disminuye gradualmente hasta estabilizarse alrededor de 3.5 en los años más recientes.
#  * Volatilidad Inicial: En los primeros años (2007-2009), el gráfico muestra una alta volatilidad, con fluctuaciones significativas en el promedio de estrellas. Esto sugiere que hubo cambios bruscos en la percepción o calidad del servicio/producto durante ese período.
#  * Estabilización Posterior: A partir de 2010, el promedio de estrellas se estabiliza y muestra menos fluctuaciones. Esto podría indicar que la calidad del servicio/producto se volvió más consistente o que la percepción del cliente se volvió más estable.
#  * Puntos Atípicos: Se observan algunos puntos atípicos en el gráfico, especialmente en los primeros años. Estos puntos representan meses con promedios de estrellas significativamente más altos o más bajos que el promedio general.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

# Inicializar el analizador de sentimiento
sia = SentimentIntensityAnalyzer()

# Función para obtener el sentimiento de la reseña
def get_sentiment(text):
    sentiment_score = sia.polarity_scores(text)['compound']
    if sentiment_score > 0:
        return 'Positivo'
    elif sentiment_score < 0:
        return 'Negativo'
    else:
        return 'Neutro'

# Aplicar el análisis de sentimiento
chunk['sentiment'] = chunk['text'].apply(get_sentiment)

# Graficar la distribución de los sentimientos
plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment', data=chunk, palette='Set2')
plt.title('Distribución de Sentimientos de las Reseñas')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yanin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\2637391200.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=chunk, palette='Set2')

# %% [markdown]
# * Sentimiento Dominante: La barra azul, que representa un sentimiento específico (asumiremos que es "Positivo" ), tiene una frecuencia significativamente mayor que la otra barra. Esto indica que la mayoría de las reseñas expresan este sentimiento dominante.
#  * Sentimiento Minoritario: La barra rosa, que representa otro sentimiento (asumiremos que es "Negativo"), tiene una frecuencia mucho menor. Esto sugiere que este sentimiento es menos común en las reseñas.
#  * Desequilibrio en los Sentimientos: Existe un claro desequilibrio en la distribución de los sentimientos. El sentimiento dominante aparece con mucha más frecuencia que el sentimiento minoritario

# %%
# Cargar el archivo JSON de negocios en un DataFrame

df_business = pd.read_pickle(r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\business_modificado.pkl")
# Verificar las primeras filas para asegurarse de que las columnas de interés existen
print(df_business.head())

# Filtrar columnas numéricas que puedan ser relevantes para la correlación
# Suponiendo que 'stars' y 'review_count' son de interés
df_business_filtered = df_business[['stars', 'review_count']]

# Calcular la matriz de correlación
correlation = df_business_filtered.corr()

import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación
correlation = df_business_filtered.corr()

# Graficar la matriz de correlación utilizando un mapa de calor (heatmap)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Matriz de Correlación entre "stars" y "review_count"')
plt.show()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara  <NA>       93101
# 1  87 Grasso Plaza Shopping Center         Affton  <NA>       63123
# 2             5255 E Broadway Blvd         Tucson  <NA>       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  [Doctors, Traditional Chinese Medicine, Naturo...
# 1  [Shipping Centers, Local Services, Notaries, M...
# 2  [Department Stores, Shopping, Fashion, Home & ...
# 3  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
# 4                        [Brewpubs, Breweries, Food]
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
#  No hay una relación lineal fuerte entre el número de estrellas que recibe un negocio y el número de reseñas que tiene. En otras palabras, tener más reseñas no necesariamente significa que un negocio tendrá más estrellas, y viceversa.
#  * La correlación de 0.06 es muy cercana a cero, lo que sugiere que otras variables podrían estar influyendo en el número de estrellas y reseñas.

# %% [markdown]
# conclusion: el análisis de los datos de reseñas revela patrones interesantes sobre el comportamiento de los usuarios y la percepción de los productos o servicios. Desde la perspectiva estadística, observamos que las calificaciones de estrellas tienden a polarizarse, con una alta frecuencia de reseñas de 5 estrellas y 1 estrella, lo que sugiere que los usuarios suelen expresar opiniones extremas. Además, existe una correlación positiva entre los votos útiles, graciosos y cool, lo que indica que las reseñas que son consideradas útiles también tienden a ser vistas como graciosas y geniales.
# Los gráficos de dispersión y los boxplots confirman la presencia de valores atípicos, lo que sugiere que hay algunas reseñas que destacan por su utilidad, humor o genialidad. La distribución asimétrica de los votos útiles, graciosos y cool indica que hay factores adicionales, además de la calificación con estrellas, que influyen en cómo los usuarios perciben y valoran las reseñas.
# El histograma de las estrellas muestra una distribución sesgada hacia la derecha, lo que refuerza la idea de que la mayoría de las reseñas tienen calificaciones altas. Sin embargo, la presencia de un número significativo de reseñas de 1 estrella indica que también hay un grupo de usuarios que expresan fuertes críticas.
# Finalmente, el gráfico de los 10 usuarios más activos revela que hay una gran disparidad en la actividad de los usuarios. Algunos usuarios son mucho más activos que otros, lo que sugiere que podrían tener un papel importante en la comunidad o plataforma.
# Implicaciones:
#  * Percepción del producto/servicio: Las calificaciones extremas sugieren que los productos o servicios generan experiencias muy positivas o muy negativas.
#  * Calidad de las reseñas: La correlación entre los votos útiles, graciosos y cool indica que la calidad del contenido de la reseña es importante para los usuarios.
#  * Comunidad: Los usuarios más activos podrían ser influyentes y tener un impacto significativo en la plataforma.
#  * Necesidad de investigación adicional: Sería útil investigar los factores que influyen en la percepción de las reseñas y la actividad de los usuarios.
# En resumen, el análisis de los datos de reseñas proporciona información valiosa sobre el comportamiento de los usuarios y la percepción de los productos o servicios. Esta información puede ser utilizada para mejorar la calidad de las reseñas, fomentar la participación de los usuarios y comprender mejor las necesidades y preferencias de los clientes.

# %% [markdown]
# EDA user.parquet

# %% [markdown]
# Columnas son:
# 'user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'

# %%
import pandas as pd

# Ruta del archivo 
file_path = r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\user.parquet"

# Cargar el archivo Parquet
df= pd.read_parquet(file_path)

# Mostrar las primeras filas
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[137], line 7
#       4 file_path = r"C:\Users\yanin\OneDrive\Desktop\proyecto final\archivos\yelp\user.parquet"
#       6 # Cargar el archivo Parquet
# ----> 7 df= pd.read_parquet(file_path)
#       9 # Mostrar las primeras filas
#      10 print(df.head())
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:274, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
# --> 274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#     277         filesystem=filesystem,
#     278         filters=filters,
#     279         **kwargs,
#     280     )
#     281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\parquet\core.py:1843, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1831     # TODO test that source is not a directory or a list
#    1832     dataset = ParquetFile(
#    1833         source, read_dictionary=read_dictionary,
#    1834         memory_map=memory_map, buffer_size=buffer_size,
#    (...)
#    1840         page_checksum_verification=page_checksum_verification,
#    1841     )
# -> 1843 return dataset.read(columns=columns, use_threads=use_threads,
#    1844                     use_pandas_metadata=use_pandas_metadata)
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\parquet\core.py:1485, in ParquetDataset.read(self, columns, use_threads, use_pandas_metadata)
#    1477         index_columns = [
#    1478             col for col in _get_pandas_index_columns(metadata)
#    1479             if not isinstance(col, dict)
#    1480         ]
#    1481         columns = (
#    1482             list(columns) + list(set(index_columns) - set(columns))
#    1483         )
# -> 1485 table = self._dataset.to_table(
#    1486     columns=columns, filter=self._filter_expression,
#    1487     use_threads=use_threads
#    1488 )
#    1490 # if use_pandas_metadata, restore the pandas metadata (which gets
#    1491 # lost if doing a specific `columns` selection in to_table)
#    1492 if use_pandas_metadata:
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\_dataset.pyx:574, in pyarrow._dataset.Dataset.to_table()
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\_dataset.pyx:3865, in pyarrow._dataset.Scanner.to_table()
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File c:\Users\yanin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowMemoryError: realloc of size 1169326080 failed

# %%
# Mostrar información general del DataFrame
print("📌 Información del DataFrame:")
print(df.info(), "\n")
# Out:
# 📌 Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB
# None

# %%
# Contar valores nulos por columna
print("📌 Valores nulos por columna:")
print(df.isnull().sum(), "\n")
# Out:
# 📌 Valores nulos por columna:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %%
# Contar valores duplicados
print(f"📌 Filas duplicadas: {df.duplicated().sum()} \n")
# Out:
# 📌 Filas duplicadas: 117700

# %%
# Eliminar duplicados y mantener solo la primera aparición
df_user = df.drop_duplicates()

# Verificar si aún hay duplicados
print(f"📌 Filas duplicadas después de limpiar: {df_user.duplicated().sum()}")

# Mostrar el tamaño del DataFrame antes y después
print(f"📌 Tamaño original: {df.shape[0]} filas")
print(f"📌 Tamaño después de limpiar: {df_user.shape[0]} filas")
# Out:
# 📌 Filas duplicadas después de limpiar: 0
# 📌 Tamaño original: 2105597 filas
# 📌 Tamaño después de limpiar: 1987897 filas

# %%
# Mostrar tipos de datos
print("📌 Tipos de datos:")
print(df_user.dtypes)
# Out:
# 📌 Tipos de datos:
# user_id                object
# name                   object
# review_count            int64
# yelping_since          object
# useful                  int64
# funny                   int64
# cool                    int64
# elite                  object
# friends                object
# fans                    int64
# average_stars         float64
# compliment_hot          int64
# compliment_more         int64
# compliment_profile      int64
# compliment_cute         int64
# compliment_list         int64
# compliment_note         int64
# compliment_plain        int64
# compliment_cool         int64
# compliment_funny        int64
# compliment_writer       int64
# compliment_photos       int64
# dtype: object

# %%
# Resumen estadístico de las columnas numéricas
print("\nResumen estadístico de las columnas numéricas:")
print(df_user.describe())
# Out:
# Resumen estadístico de las columnas numéricas:
#        review_count        useful         funny          cool          fans  \
# count  1.987897e+06  1.987897e+06  1.987897e+06  1.987897e+06  1.987897e+06
# mean   2.339441e+01  4.229634e+01  1.697054e+01  2.379291e+01  1.465740e+00
# std    8.256699e+01  6.414806e+02  4.078034e+02  5.653513e+02  1.813075e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    5.000000e+00  3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.700000e+01  1.300000e+01  2.000000e+00  3.000000e+00  0.000000e+00
# max    1.747300e+04  2.062960e+05  1.858230e+05  1.998780e+05  1.249700e+04
#
#        average_stars  compliment_hot  compliment_more  compliment_profile  \
# count   1.987897e+06    1.987897e+06     1.987897e+06        1.987897e+06
# mean    3.630494e+00    1.807072e+00     2.922631e-01        1.793176e-01
# std     1.183337e+00    7.360184e+01     1.282467e+01        1.515525e+01
# min     1.000000e+00    0.000000e+00     0.000000e+00        0.000000e+00
# 25%     3.000000e+00    0.000000e+00     0.000000e+00        0.000000e+00
# 50%     3.880000e+00    0.000000e+00     0.000000e+00        0.000000e+00
# 75%     4.560000e+00    0.000000e+00     0.000000e+00        0.000000e+00
# max     5.000000e+00    2.578400e+04     1.350100e+04        1.418000e+04
#
#        compliment_cute  compliment_list  compliment_note  compliment_plain  \
# count     1.987897e+06     1.987897e+06     1.987897e+06      1.987897e+06
# mean      1.336493e-01     6.390723e-02     1.443135e+00      3.011841e+00
# std       1.135682e+01     1.004363e+01     6.016790e+01      1.193898e+02
# min       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 25%       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 50%       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 75%       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# max       1.365400e+04     1.266900e+04     5.903100e+04      1.010970e+05
#
#        compliment_cool  compliment_funny  compliment_writer  compliment_photos
# count     1.987897e+06      1.987897e+06       1.987897e+06       1.987897e+06
# mean      2.829308e+00      2.829308e+00       1.056448e+00       1.226859e+00
# std       9.666385e+01      9.666385e+01       3.217973e+01       9.515751e+01
# min       0.000000e+00      0.000000e+00       0.000000e+00       0.000000e+00
# 25%       0.000000e+00      0.000000e+00       0.000000e+00       0.000000e+00
# 50%       0.000000e+00      0.000000e+00       0.000000e+00       0.000000e+00
# 75%       0.000000e+00      0.000000e+00       0.000000e+00       0.000000e+00
# max       4.996700e+04      4.996700e+04       1.593400e+04       8.263000e+04

# %%
import numpy as np

# Función para detectar valores atípicos con IQR
def detectar_outliers_iqr(df_user):
    outliers = {}
    for col in df_user.select_dtypes(include=np.number):  # Solo columnas numéricas
        Q1 = df_user[col].quantile(0.25)  # Primer cuartil (25%)
        Q3 = df_user[col].quantile(0.75)  # Tercer cuartil (75%)
        IQR = Q3 - Q1  # Rango intercuartílico
        limite_inferior = Q1 - 1.5 * IQR
        limite_superior = Q3 + 1.5 * IQR

        # Contar outliers
        num_outliers = df_user[(df_user[col] < limite_inferior) | (df_user[col] > limite_superior)].shape[0]
        outliers[col] = num_outliers

    return outliers

# Detectar valores atípicos
outliers_detectados = detectar_outliers_iqr(df_user)

print("📌 Cantidad de valores atípicos por columna:")
print(outliers_detectados)
# Out:
# 📌 Cantidad de valores atípicos por columna:
# {'review_count': 235589, 'useful': 262744, 'funny': 313004, 'cool': 283271, 'fans': 410027, 'average_stars': 0, 'compliment_hot': 154215, 'compliment_more': 148788, 'compliment_profile': 61771, 'compliment_cute': 40767, 'compliment_list': 17194, 'compliment_note': 316878, 'compliment_plain': 345377, 'compliment_cool': 240003, 'compliment_funny': 240003, 'compliment_writer': 198986, 'compliment_photos': 124883}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear boxplots para todas las columnas numéricas
plt.figure(figsize=(12, 6))  # Ajusta el tamaño de la figura
sns.boxplot(data=df_user.select_dtypes(include=np.number))  # Seleccionamos solo columnas numéricas

# Agregar título y etiquetas
plt.title("Detección de Valores Atípicos con Boxplot")
plt.xticks(rotation=90)  # Rotar las etiquetas de las columnas si hay muchas
plt.show()

# %% [markdown]
# la imagen muestra un gráfico de boxplot que se utiliza para detectar valores atípicos en diferentes variables del dataset de Yelp. El gráfico revela que varias variables tienen una distribución sesgada a la derecha y contienen valores atípicos

# %%
# Análisis de la distribución de algunas columnas
import matplotlib.pyplot as plt



# Comparar 'average_stars' y 'review_count'
plt.figure(figsize=(8, 6))
plt.scatter(df_user['review_count'], df_user['average_stars'], color='green', alpha=0.5)
plt.title('Promedio de estrellas vs Número de reseñas')
plt.xlabel('Número de reseñas')
plt.ylabel('Promedio de estrellas')
plt.show()

# Ver si hay alguna relación entre los votos útiles y el número de reseñas
plt.figure(figsize=(8, 6))
plt.scatter(df_user['useful'], df_user['review_count'], color='purple', alpha=0.5)
plt.title('Votos útiles vs Número de reseñas')
plt.xlabel('Votos útiles')
plt.ylabel('Número de reseñas')
plt.show()

# Ver la lista de amigos de un usuario específico
user_id = "Ha3iJu77CxlrFm-vQRs_8g"
user_friends = df_user[df_user['user_id'] == user_id]['friends']
print(f"\nAmigos de {user_id}:")
print(user_friends)
# Out:
# Amigos de Ha3iJu77CxlrFm-vQRs_8g:
# Series([], Name: friends, dtype: object)

# %% [markdown]
# -el gráfico sugiere que los negocios con más reseñas tienden a tener mejores calificaciones.
# -El gráfico sugiere que no hay una correlación fuerte entre el número de votos útiles y el número de reseñas. Esto significa que un negocio con muchas reseñas no necesariamente tendrá muchos votos útiles, y viceversa.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de que las columnas están correctamente convertidas a tipo numérico
df_user['review_count'] = pd.to_numeric(df_user['review_count'], errors='coerce')
df_user['average_stars'] = pd.to_numeric(df_user['average_stars'], errors='coerce')

# 1. Distribución de review_count
plt.figure(figsize=(10, 6))
sns.histplot(df_user['review_count'], kde=True, color='skyblue')
plt.title('Distribución de la cantidad de reseñas por usuario')
plt.xlabel('Cantidad de reseñas')
plt.ylabel('Frecuencia')
plt.show()

# 2. Promedio de average_stars
plt.figure(figsize=(10, 6))
sns.histplot(df_user['average_stars'], kde=True, color='orange')
plt.title('Distribución de las calificaciones promedio')
plt.xlabel('Calificación promedio')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# el gráfico revela una distribución interesante de la cantidad de reseñas por usuario, con implicaciones importantes para la participación de los usuarios y la reputación de los negocios en la plataforma

# %% [markdown]
# la distribución de las calificaciones promedio sugiere que los usuarios de la plataforma tienden a dejar calificaciones extremas, ya sea muy bajas o muy altas. Esto podría indicar que:
#
# Los usuarios están más motivados a dejar reseñas cuando tienen experiencias muy negativas o muy positivas.
# Puede haber una falta de reseñas para negocios con calificaciones promedio.
# Podría haber un sesgo en las reseñas, con usuarios que solo dejan reseñas cuando tienen experiencias extremas.

# %%
# 3. Comparación de cumplidos
compliments_columns = ['compliment_hot', 'compliment_more', 'compliment_profile', 
                       'compliment_cute', 'compliment_list', 'compliment_note', 'compliment_plain']

# Asegurémonos de que las columnas de cumplidos son numéricas
df_user[compliments_columns] = df_user[compliments_columns].apply(pd.to_numeric, errors='coerce')

compliments_sum = df_user[compliments_columns].sum()

plt.figure(figsize=(12, 6))
compliments_sum.plot(kind='bar', color='lightcoral')
plt.title('Total de cumplidos por tipo')
plt.xlabel('Tipo de cumplido')
plt.ylabel('Total de cumplidos')
plt.xticks(rotation=45)
plt.show()

# 4. Relación entre review_count y average_stars
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_user, x='review_count', y='average_stars', color='green')
plt.title('Relación entre cantidad de reseñas y calificación promedio')
plt.xlabel('Cantidad de reseñas')
plt.ylabel('Calificación promedio')
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\699591024.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['review_count'] = pd.to_numeric(df_user['review_count'], errors='coerce')
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\699591024.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['average_stars'] = pd.to_numeric(df_user['average_stars'], errors='coerce')
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\699591024.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user[compliments_columns] = df_user[compliments_columns].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# l gráfico revela una distribución interesante de los tipos de cumplidos, con el tipo "compliment_plain" siendo el más común

# %% [markdown]
# gráfico sugiere que no hay una correlación fuerte entre la cantidad de reseñas y la calificación promedio. Esto significa que un negocio con muchas reseñas no necesariamente tendrá una calificación alta, y viceversa.

# %%
import matplotlib.pyplot as plt

# Asegúrate de que la columna 'year_joined' esté presente en `df_user`
# Si no está, extraemos el año de la fecha de registro 'yelping_since'
df_user['year_joined'] = df_user['yelping_since'].dt.year

# Contamos los usuarios por año
users_per_year = df_user['year_joined'].value_counts().sort_index()

# Creamos el gráfico de barras
plt.figure(figsize=(12, 6))  # Ajusta el tamaño de la figura
users_per_year.plot(kind='bar', color='skyblue')

# Títulos y etiquetas
plt.title('Número de Usuarios por Año de Registro')
plt.xlabel('Año de Registro')
plt.ylabel('Número de Usuarios')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\262371824.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['year_joined'] = df_user['yelping_since'].dt.year

# %% [markdown]
# la imagen muestra un gráfico de barras que representa el número de usuarios registrados en Yelp por año. El gráfico revela una tendencia al alza en el número de usuarios registrados hasta 2016, seguida de una disminución en los años más recientes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de tener una columna 'year_joined' que representa el año en que los usuarios se registraron
df_user['year_joined'] = df_user['yelping_since'].dt.year

# Calculamos el promedio de reseñas por año de registro
average_reviews_per_year = df_user.groupby('year_joined')['review_count'].mean()

# Generamos el gráfico de líneas
plt.figure(figsize=(10, 6))
sns.lineplot(data=average_reviews_per_year)

# Títulos y etiquetas
plt.title('Promedio de Reseñas por Año de Registro')
plt.xlabel('Año de Registro')
plt.ylabel('Promedio de Reseñas')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\1040386058.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['year_joined'] = df_user['yelping_since'].dt.year

# %% [markdown]
# el gráfico sugiere que los negocios registrados en Yelp alrededor de 2005 recibieron un promedio de reseñas significativamente mayor en comparación con los negocios registrados en años posteriores.

# %%
from sklearn.cluster import KMeans

# Seleccionamos las columnas 'review_count' y 'fans' para la segmentación
features = df_user[['review_count', 'fans']]

# Aplicamos K-means para crear 3 clusters
kmeans = KMeans(n_clusters=3)
df_user['cluster'] = kmeans.fit_predict(features)

# Generamos el gráfico de dispersión
plt.figure(figsize=(10, 6))

# Usamos seaborn para graficar los puntos de datos por clúster
sns.scatterplot(x='review_count', y='fans', hue='cluster', data=df_user, palette='Set1', alpha=0.6)

# Títulos y etiquetas
plt.title('Segmentación de Usuarios por Reseñas y Fans')
plt.xlabel('Número de Reseñas')
plt.ylabel('Número de Fans')

# Mostrar leyenda
plt.legend(title='Cluster')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yanin\AppData\Local\Temp\ipykernel_23236\4215912406.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['cluster'] = kmeans.fit_predict(features)

# %% [markdown]
# la imagen muestra un gráfico de dispersión que representa la segmentación de usuarios basada en el número de reseñas y fans. El gráfico revela que los usuarios se pueden agrupar en diferentes clústeres según estas dos características.

# %% [markdown]
# Resumen estadístico:
# Se examinaron las estadísticas descriptivas de varias columnas numéricas, como review_count, useful, funny, cool, fans y average_stars.
# Se observó que algunas variables, como review_count y las relacionadas con los cumplidos, presentan una distribución sesgada a la derecha, con valores atípicos.
# Detección de valores atípicos:
# Se utilizó un gráfico de boxplot para identificar visualmente los valores atípicos en las variables numéricas.
# Se confirmó la presencia de valores atípicos en varias variables, lo que sugiere la existencia de usuarios con un comportamiento excepcional en la plataforma.
# Tendencia de registro de usuarios:
# Se analizó la evolución del número de usuarios registrados en Yelp a lo largo del tiempo mediante un gráfico de barras.
# Se identificó una tendencia al alza en el número de registros hasta 2016, seguida de una disminución en los años más recientes.
# Relación entre votos útiles y reseñas:
# Se exploró la relación entre el número de votos útiles y el número de reseñas mediante un gráfico de dispersión.
# Se observó una tendencia positiva, lo que indica que los usuarios con más reseñas tienden a recibir más votos útiles.
# Segmentación de usuarios:
# Se realizó una segmentación de usuarios basada en el número de reseñas y fans utilizando un algoritmo de clustering (K-means).
# Se identificaron tres grupos de usuarios con características distintas en términos de reseñas y fans.
# Correlación entre variables:
# Se examinó la correlación entre las variables numéricas mediante un mapa de calor.
# Se encontraron correlaciones positivas moderadas entre el número de reseñas y otras variables, así como correlaciones fuertes entre los votos útiles, divertidos y geniales.
# Conclusión general:
#
# El análisis reveló patrones interesantes en los datos de Yelp, como la presencia de valores atípicos, tendencias en el registro de usuarios y relaciones entre variables.
# Estos hallazgos pueden ser útiles para comprender mejor el comportamiento de los usuarios en la plataforma y para tomar decisiones informadas sobre estrategias de negocio
